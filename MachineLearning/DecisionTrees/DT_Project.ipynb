# %% [markdown]
# _____
# # Decision Trees

# %% [markdown]
# # Import Libraries
#
# **Import the usual libraries for pandas and plotting. You can import sklearn later on.**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Get the Data
#
# ** Use pandas to read loan_data.csv as a dataframe called loans.**

# %%
loans = pd.read_csv('loan_data.csv')

# %%
loans.head()
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# 0            0        0               0
# 1            0        0               0
# 2            0        0               0
# 3            0        0               0
# 4            1        0               0

# %% [markdown]
# ** Check out the info(), head(), and describe() methods on loans.**

# %%
loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
# credit.policy        9578 non-null int64
# purpose              9578 non-null object
# int.rate             9578 non-null float64
# installment          9578 non-null float64
# log.annual.inc       9578 non-null float64
# dti                  9578 non-null float64
# fico                 9578 non-null int64
# days.with.cr.line    9578 non-null float64
# revol.bal            9578 non-null int64
# revol.util           9578 non-null float64
# inq.last.6mths       9578 non-null int64
# delinq.2yrs          9578 non-null int64
# pub.rec              9578 non-null int64
# not.fully.paid       9578 non-null int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
loans.describe()
# Out:
#        credit.policy     int.rate  installment  log.annual.inc          dti  \
# count    9578.000000  9578.000000  9578.000000     9578.000000  9578.000000
# mean        0.804970     0.122640   319.089413       10.932117    12.606679
# std         0.396245     0.026847   207.071301        0.614813     6.883970
# min         0.000000     0.060000    15.670000        7.547502     0.000000
# 25%         1.000000     0.103900   163.770000       10.558414     7.212500
# 50%         1.000000     0.122100   268.950000       10.928884    12.665000
# 75%         1.000000     0.140700   432.762500       11.291293    17.950000
# max         1.000000     0.216400   940.140000       14.528354    29.960000
#
#               fico  days.with.cr.line     revol.bal   revol.util  \
# count  9578.000000        9578.000000  9.578000e+03  9578.000000
# mean    710.846314        4560.767197  1.691396e+04    46.799236
# std      37.970537        2496.930377  3.375619e+04    29.014417
# min     612.000000         178.958333  0.000000e+00     0.000000
# 25%     682.000000        2820.000000  3.187000e+03    22.600000
# 50%     707.000000        4139.958333  8.596000e+03    46.300000
# 75%     737.000000        5730.000000  1.824950e+04    70.900000
# max     827.000000       17639.958330  1.207359e+06   119.000000
#
#        inq.last.6mths  delinq.2yrs      pub.rec  not.fully.paid
# count     9578.000000  9578.000000  9578.000000     9578.000000
# mean         1.577469     0.163708     0.062122        0.160054
# std          2.200245     0.546215     0.262126        0.366676
# min          0.000000     0.000000     0.000000        0.000000
# 25%          0.000000     0.000000     0.000000        0.000000
# 50%          1.000000     0.000000     0.000000        0.000000
# 75%          2.000000     0.000000     0.000000        0.000000
# max         33.000000    13.000000     5.000000        1.000000

# %%
loans.head()
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# 0            0        0               0
# 1            0        0               0
# 2            0        0               0
# 3            0        0               0
# 4            1        0               0

# %% [markdown]
# # Exploratory Data Analysis
#
# Let's do some data visualization! We'll use seaborn and pandas built-in plotting capabilities, but feel free to use whatever library you want. Don't worry about the colors matching, just worry about getting the main idea of the plot.
#
# ** Create a histogram of two FICO distributions on top of each other, one for each credit.policy outcome.**
#
# *Note: This is pretty tricky, feel free to reference the solutions. You'll probably need one line of code for each histogram, I also recommend just using pandas built in .hist()*

# %%
plt.figure(figsize=(10,6))
loans[loans['credit.policy']==1]['fico'].hist(alpha=0.5,color='blue',
                                              bins=30,label='Credit.Policy=1')
loans[loans['credit.policy']==0]['fico'].hist(alpha=0.5,color='red',
                                              bins=30,label='Credit.Policy=0')
plt.legend()
plt.xlabel('FICO')

# %% [markdown]
# ** Create a similar figure, except this time select by the not.fully.paid column.**

# %%
plt.figure(figsize=(10,6))
loans[loans['not.fully.paid']==1]['fico'].hist(alpha=0.5,color='blue',
                                              bins=30,label='not.fully.paid=1')
loans[loans['not.fully.paid']==0]['fico'].hist(alpha=0.5,color='red',
                                              bins=30,label='not.fully.paid=0')
plt.legend()
plt.xlabel('FICO')

# %% [markdown]
# ** Create a countplot using seaborn showing the counts of loans by purpose, with the color hue defined by not.fully.paid. **

# %%
plt.figure(figsize=(11,7))
sns.countplot(x='purpose',hue='not.fully.paid',data=loans,palette='Set1')

# %% [markdown]
# ** Let's see the trend between FICO score and interest rate. Recreate the following jointplot.**

# %%
sns.jointplot(x='fico',y='int.rate',data=loans,color='purple')

# %% [markdown]
# # Setting up the Data

# %%
loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
# credit.policy        9578 non-null int64
# purpose              9578 non-null object
# int.rate             9578 non-null float64
# installment          9578 non-null float64
# log.annual.inc       9578 non-null float64
# dti                  9578 non-null float64
# fico                 9578 non-null int64
# days.with.cr.line    9578 non-null float64
# revol.bal            9578 non-null int64
# revol.util           9578 non-null float64
# inq.last.6mths       9578 non-null int64
# delinq.2yrs          9578 non-null int64
# pub.rec              9578 non-null int64
# not.fully.paid       9578 non-null int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %% [markdown]
# ## Categorical Features

# %%
cat_feats = ['purpose']

# %%
final_data = pd.get_dummies(loans,columns=cat_feats,drop_first=True)

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 19 columns):
# credit.policy                 9578 non-null int64
# int.rate                      9578 non-null float64
# installment                   9578 non-null float64
# log.annual.inc                9578 non-null float64
# dti                           9578 non-null float64
# fico                          9578 non-null int64
# days.with.cr.line             9578 non-null float64
# revol.bal                     9578 non-null int64
# revol.util                    9578 non-null float64
# inq.last.6mths                9578 non-null int64
# delinq.2yrs                   9578 non-null int64
# pub.rec                       9578 non-null int64
# not.fully.paid                9578 non-null int64
# purpose_credit_card           9578 non-null uint8
# purpose_debt_consolidation    9578 non-null uint8
# purpose_educational           9578 non-null uint8
# purpose_home_improvement      9578 non-null uint8
# purpose_major_purchase        9578 non-null uint8
# purpose_small_business        9578 non-null uint8
# dtypes: float64(6), int64(7), uint8(6)
# memory usage: 1.0 MB

# %% [markdown]
# ## Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X = final_data.drop('not.fully.paid',axis=1)
y = final_data['not.fully.paid']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=101)

# %% [markdown]
# ## Training a Decision Tree Model

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# **Create an instance of DecisionTreeClassifier() called dtree and fit it to the training data.**

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %% [markdown]
# ## Predictions and Evaluation of Decision Tree

# %%
predictions = dtree.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,predictions))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.85      0.82      0.84      2431
#           1       0.19      0.23      0.21       443
#
# avg / total       0.75      0.73      0.74      2874

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[1991  440]
#  [ 341  102]]

# %%
print(classification_report(y_test,predictions))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.85      0.82      0.84      2431
#           1       0.19      0.23      0.21       443
#
# avg / total       0.75      0.73      0.74      2874

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,predictions))
# Out:
# 0.728253305498

# %%
from IPython.display import Image  
from sklearn.externals.six import StringIO  
from sklearn.tree import export_graphviz
import pydotplus

features = list(final_data.drop('not.fully.paid',axis=1).columns)
features
# Out:
# ['credit.policy',
#  'int.rate',
#  'installment',
#  'log.annual.inc',
#  'dti',
#  'fico',
#  'days.with.cr.line',
#  'revol.bal',
#  'revol.util',
#  'inq.last.6mths',
#  'delinq.2yrs',
#  'pub.rec',
#  'purpose_credit_card',
#  'purpose_debt_consolidation',
#  'purpose_educational',
#  'purpose_home_improvement',
#  'purpose_major_purchase',
#  'purpose_small_business']

# %%
dot_data = StringIO()  
export_graphviz(dtree, out_file=dot_data,feature_names=features,filled=True,rounded=True)

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())

# %%
graph.write_jpg('dt_loandata.jpg')
# Out:
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.662642 to fit
# True

# %%
print(dot_data.getvalue())
# Out:
# digraph Tree {
# node [shape=box, style="filled, rounded", color="black", fontname=helvetica] ;
# edge [fontname=helvetica] ;
# 0 [label="credit.policy <= 0.5\ngini = 0.2723\nsamples = 6704\nvalue = [5614, 1090]", fillcolor="#e58139cd"] ;
# 1 [label="installment <= 349.935\ngini = 0.408\nsamples = 1317\nvalue = [941, 376]", fillcolor="#e5813999"] ;
# 0 -> 1 [labeldistance=2.5, labelangle=45, headlabel="True"] ;
# 2 [label="inq.last.6mths <= 6.5\ngini = 0.3784\nsamples = 943\nvalue = [704, 239]", fillcolor="#e58139a8"] ;
# 1 -> 2 ;
# 3 [label="int.rate <= 0.0835\ngini = 0.3602\nsamples = 815\nvalue = [623, 192]", fillcolor="#e58139b0"] ;
# 2 -> 3 ;
# 4 [label="gini = 0.0\nsamples = 26\nvalue = [26, 0]", fillcolor="#e58139ff"] ;
# 3 -> 4 ;
# 5 [label="purpose_small_business <= 0.5\ngini = 0.3683\nsamples = 789\nvalue = [597, 192]", fillcolor="#e58139ad"] ;
# 3 -> 5 ;
# 6 [label="revol.util <= 50.95\ngini = 0.3616\nsamples = 768\nvalue = [586, 182]", fillcolor="#e58139b0"] ;
# 5 -> 6 ;
# 7 [label="revol.util <= 1.35\ngini = 0.3134\nsamples = 329\nvalue = [265, 64]", fillcolor="#e58139c1"] ;
# 6 -> 7 ;
# 8 [label="dti <= 6.54\ngini = 0.4704\nsamples = 37\nvalue = [23, 14]", fillcolor="#e5813964"] ;
# 7 -> 8 ;
# 9 [label="days.with.cr.line <= 1890.0208\ngini = 0.4444\nsamples = 18\nvalue = [6, 12]", fillcolor="#399de57f"] ;
# 8 -> 9 ;
# 10 [label="dti <= 4.245\ngini = 0.4959\nsamples = 11\nvalue = [6, 5]", fillcolor="#e581392a"] ;
# 9 -> 10 ;
# 11 [label="int.rate <= 0.1044\ngini = 0.4444\nsamples = 9\nvalue = [6, 3]", fillcolor="#e581397f"] ;
# 10 -> 11 ;
# 12 [label="dti <= 0.41\ngini = 0.5\nsamples = 6\nvalue = [3, 3]", fillcolor="#e5813900"] ;
# 11 -> 12 ;
# 13 [label="installment <= 45.205\ngini = 0.375\nsamples = 4\nvalue = [1, 3]", fillcolor="#399de5aa"] ;
# 12 -> 13 ;
# 14 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]", fillcolor="#e58139ff"] ;
# 13 -> 14 ;
# 15 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]", fillcolor="#399de5ff"] ;
# 13 -> 15 ;
# 16 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]", fillcolor="#e58139ff"] ;
# 12 -> 16 ;
# 17 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]", fillcolor="#e58139ff"] ;
# 11 -> 17 ;
# 18 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]", fillcolor="#399de5ff"] ;
# 10 -> 18 ;
# 19 [label="gini = 0.0\nsamples = 7\nvalue = [0, 7]", fillcolor="#399de5ff"] ;
# 9 -> 19 ;
# 20 [label="purpose_home_improvement <= 0.5\ngini = 0.1884\nsamples = 19\nvalue = [17, 2]", fillcolor="#e58139e1"] ;
# 8 -> 20 ;
# 21 [label="dti <= 22.42\ngini = 0.1049\nsamples = 18\nvalue = [17, 1]", fillcolor="#e58139f0"] ;
# 20 -> 21 ;
# 22 [label="gini = 0.0\nsamples = 17\nvalue = [17, 0]", fillcolor="#e58139ff"] ;
# 21 -> 22 ;
# 23 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 21 -> 23 ;
# 24 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 20 -> 24 ;
# 25 [label="log.annual.inc <= 9.8145\ngini = 0.2838\nsamples = 292\nvalue = [242, 50]", fillcolor="#e58139ca"] ;
# 7 -> 25 ;
# 26 [label="installment <= 75.165\ngini = 0.4506\nsamples = 35\nvalue = [23, 12]", fillcolor="#e581397a"] ;
# 25 -> 26 ;
# 27 [label="revol.bal <= 493.0\ngini = 0.1327\nsamples = 14\nvalue = [13, 1]", fillcolor="#e58139eb"] ;
# 26 -> 27 ;
# 28 [label="revol.util <= 15.45\ngini = 0.4444\nsamples = 3\nvalue = [2, 1]", fillcolor="#e581397f"] ;
# 27 -> 28 ;
# 29 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 28 -> 29 ;
# 30 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]", fillcolor="#e58139ff"] ;
# 28 -> 30 ;
# 31 [label="gini = 0.0\nsamples = 11\nvalue = [11, 0]", fillcolor="#e58139ff"] ;
# 27 -> 31 ;
# 32 [label="purpose_major_purchase <= 0.5\ngini = 0.4989\nsamples = 21\nvalue = [10, 11]", fillcolor="#399de517"] ;
# 26 -> 32 ;
# 33 [label="days.with.cr.line <= 6344.4795\ngini = 0.4753\nsamples = 18\nvalue = [7, 11]", fillcolor="#399de55d"] ;
# 32 -> 33 ;
# 34 [label="log.annual.inc <= 9.3015\ngini = 0.4297\nsamples = 16\nvalue = [5, 11]", fillcolor="#399de58b"] ;
# 33 -> 34 ;
# 35 [label="installment <= 188.375\ngini = 0.375\nsamples = 4\nvalue = [3, 1]", fillcolor="#e58139aa"] ;
# 34 -> 35 ;
# 36 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]", fillcolor="#e58139ff"] ;
# 35 -> 36 ;
# 37 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 35 -> 37 ;
# 38 [label="dti <= 1.73\ngini = 0.2778\nsamples = 12\nvalue = [2, 10]", fillcolor="#399de5cc"] ;
# 34 -> 38 ;
# 39 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]", fillcolor="#e58139ff"] ;
# 38 -> 39 ;
# 40 [label="revol.util <= 13.1\ngini = 0.1653\nsamples = 11\nvalue = [1, 10]", fillcolor="#399de5e6"] ;
# 38 -> 40 ;
# 41 [label="fico <= 689.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]", fillcolor="#e5813900"] ;
# 40 -> 41 ;
# 42 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]", fillcolor="#e58139ff"] ;
# 41 -> 42 ;
# 43 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 41 -> 43 ;
# 44 [label="gini = 0.0\nsamples = 9\nvalue = [0, 9]", fillcolor="#399de5ff"] ;
# 40 -> 44 ;
# 45 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]", fillcolor="#e58139ff"] ;
# 33 -> 45 ;
# 46 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]", fillcolor="#e58139ff"] ;
# 32 -> 46 ;
# 47 [label="revol.bal <= 5048.5\ngini = 0.252\nsamples = 257\nvalue = [219, 38]", fillcolor="#e58139d3"] ;
# 25 -> 47 ;
# 48 [label="int.rate <= 0.1948\ngini = 0.1703\nsamples = 149\nvalue = [135, 14]", fillcolor="#e58139e5"] ;
# 47 -> 48 ;
# 49 [label="int.rate <= 0.1411\ngini = 0.1602\nsamples = 148\nvalue = [135, 13]", fillcolor="#e58139e6"] ;
# 48 -> 49 ;
# 50 [label="purpose_home_improvement <= 0.5\ngini = 0.1049\nsamples = 108\nvalue = [102, 6]", fillcolor="#e58139f0"] ;
# 49 -> 50 ;
# 51 [label="fico <= 734.5\ngini = 0.0588\nsamples = 99\nvalue = [96, 3]", fillcolor="#e58139f7"] ;
# 50 -> 51 ;
# 52 [label="log.annual.inc <= 11.5373\ngini = 0.0412\nsamples = 95\nvalue = [93, 2]", fillcolor="#e58139fa"] ;
# 51 -> 52 ;
# 53 [label="pub.rec <= 0.5\ngini = 0.0217\nsamples = 91\nvalue = [90, 1]", fillcolor="#e58139fc"] ;
# 52 -> 53 ;
# 54 [label="gini = 0.0\nsamples = 80\nvalue = [80, 0]", fillcolor="#e58139ff"] ;
# 53 -> 54 ;
# 55 [label="dti <= 18.485\ngini = 0.1653\nsamples = 11\nvalue = [10, 1]", fillcolor="#e58139e6"] ;
# 53 -> 55 ;
# 56 [label="gini = 0.0\nsamples = 9\nvalue = [9, 0]", fillcolor="#e58139ff"] ;
# 55 -> 56 ;
# 57 [label="revol.bal <= 3817.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]", fillcolor="#e5813900"] ;
# 55 -> 57 ;
# 58 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 57 -> 58 ;
# 59 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]", fillcolor="#e58139ff"] ;
# 57 -> 59 ;
# 60 [label="revol.bal <= 1803.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]", fillcolor="#e58139aa"] ;
# 52 -> 60 ;
# 61 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]", fillcolor="#e58139ff"] ;
# 60 -> 61 ;
# 62 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 60 -> 62 ;
# 63 [label="revol.util <= 21.2\ngini = 0.375\nsamples = 4\nvalue = [3, 1]", fillcolor="#e58139aa"] ;
# 51 -> 63 ;
# 64 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]", fillcolor="#e58139ff"] ;
# 63 -> 64 ;
# 65 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 63 -> 65 ;
# 66 [label="days.with.cr.line <= 3360.0\ngini = 0.4444\nsamples = 9\nvalue = [6, 3]", fillcolor="#e581397f"] ;
# 50 -> 66 ;
# 67 [label="gini = 0.0\nsamples = 4\nvalue = [4, 0]", fillcolor="#e58139ff"] ;
# 66 -> 67 ;
# 68 [label="dti <= 4.94\ngini = 0.48\nsamples = 5\nvalue = [2, 3]", fillcolor="#399de555"] ;
# 66 -> 68 ;
# 69 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]", fillcolor="#e58139ff"] ;
# 68 -> 69 ;
# 70 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]", fillcolor="#399de5ff"] ;
# 68 -> 70 ;
# 71 [label="revol.bal <= 251.0\ngini = 0.2887\nsamples = 40\nvalue = [33, 7]", fillcolor="#e58139c9"] ;
# 49 -> 71 ;
# 72 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 71 -> 72 ;
# 73 [label="log.annual.inc <= 11.0568\ngini = 0.2604\nsamples = 39\nvalue = [33, 6]", fillcolor="#e58139d1"] ;
# 71 -> 73 ;
# 74 [label="log.annual.inc <= 11.0185\ngini = 0.3457\nsamples = 27\nvalue = [21, 6]", fillcolor="#e58139b6"] ;
# 73 -> 74 ;
# 75 [label="days.with.cr.line <= 4934.5\ngini = 0.2688\nsamples = 25\nvalue = [21, 4]", fillcolor="#e58139ce"] ;
# 74 -> 75 ;
# 76 [label="installment <= 284.93\ngini = 0.1653\nsamples = 22\nvalue = [20, 2]", fillcolor="#e58139e6"] ;
# 75 -> 76 ;
# 77 [label="dti <= 1.56\ngini = 0.0907\nsamples = 21\nvalue = [20, 1]", fillcolor="#e58139f2"] ;
# 76 -> 77 ;
# 78 [label="days.with.cr.line <= 960.0416\ngini = 0.5\nsamples = 2\nvalue = [1, 1]", fillcolor="#e5813900"] ;
# 77 -> 78 ;
# 79 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 78 -> 79 ;
# 80 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]", fillcolor="#e58139ff"] ;
# 78 -> 80 ;
# 81 [label="gini = 0.0\nsamples = 19\nvalue = [19, 0]", fillcolor="#e58139ff"] ;
# 77 -> 81 ;
# 82 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 76 -> 82 ;
# 83 [label="purpose_major_purchase <= 0.5\ngini = 0.4444\nsamples = 3\nvalue = [1, 2]", fillcolor="#399de57f"] ;
# 75 -> 83 ;
# 84 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]", fillcolor="#399de5ff"] ;
# 83 -> 84 ;
# 85 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]", fillcolor="#e58139ff"] ;
# 83 -> 85 ;
# 86 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]", fillcolor="#399de5ff"] ;
# 74 -> 86 ;
# 87 [label="gini = 0.0\nsamples = 12\nvalue = [12, 0]", fillcolor="#e58139ff"] ;
# 73 -> 87 ;
# 88 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 48 -> 88 ;
# 89 [label="revol.util <= 35.0\ngini = 0.3457\nsamples = 108\nvalue = [84, 24]", fillcolor="#e58139b6"] ;
# 47 -> 89 ;
# 90 [label="revol.util <= 34.35\ngini = 0.4403\nsamples = 55\nvalue = [37, 18]", fillcolor="#e5813983"] ;
# 89 -> 90 ;
# 91 [label="inq.last.6mths <= 1.5\ngini = 0.4032\nsamples = 50\nvalue = [36, 14]", fillcolor="#e581399c"] ;
# 90 -> 91 ;
# 92 [label="gini = 0.0\nsamples = 12\nvalue = [12, 0]", fillcolor="#e58139ff"] ;
# 91 -> 92 ;
# 93 [label="dti <= 4.965\ngini = 0.4654\nsamples = 38\nvalue = [24, 14]", fillcolor="#e581396a"] ;
# 91 -> 93 ;
# 94 [label="gini = 0.0\nsamples = 6\nvalue = [6, 0]", fillcolor="#e58139ff"] ;
# 93 -> 94 ;
# 95 [label="dti <= 10.525\ngini = 0.4922\nsamples = 32\nvalue = [18, 14]", fillcolor="#e5813939"] ;
# 93 -> 95 ;
# 96 [label="dti <= 6.67\ngini = 0.3457\nsamples = 9\nvalue = [2, 7]", fillcolor="#399de5b6"] ;
# 95 -> 96 ;
# 97 [label="revol.bal <= 11477.5\ngini = 0.4444\nsamples = 3\nvalue = [2, 1]", fillcolor="#e581397f"] ;
# 96 -> 97 ;
# 98 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]", fillcolor="#e58139ff"] ;
# 97 -> 98 ;
# 99 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 97 -> 99 ;
# 100 [label="gini = 0.0\nsamples = 6\nvalue = [0, 6]", fillcolor="#399de5ff"] ;
# 96 -> 100 ;
# 101 [label="installment <= 338.95\ngini = 0.4234\nsamples = 23\nvalue = [16, 7]", fillcolor="#e581398f"] ;
# 95 -> 101 ;
# 102 [label="log.annual.inc <= 10.5387\ngini = 0.3628\nsamples = 21\nvalue = [16, 5]", fillcolor="#e58139af"] ;
# 101 -> 102 ;
# 103 [label="log.annual.inc <= 10.3317\ngini = 0.4444\nsamples = 3\nvalue = [1, 2]", fillcolor="#399de57f"] ;
# 102 -> 103 ;
# 104 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]", fillcolor="#e58139ff"] ;
# 103 -> 104 ;
# 105 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]", fillcolor="#399de5ff"] ;
# 103 -> 105 ;
# 106 [label="revol.bal <= 5394.0\ngini = 0.2778\nsamples = 18\nvalue = [15, 3]", fillcolor="#e58139cc"] ;
# 102 -> 106 ;
# 107 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 106 -> 107 ;
# 108 [label="dti <= 25.25\ngini = 0.2076\nsamples = 17\nvalue = [15, 2]", fillcolor="#e58139dd"] ;
# 106 -> 108 ;
# 109 [label="installment <= 211.055\ngini = 0.1172\nsamples = 16\nvalue = [15, 1]", fillcolor="#e58139ee"] ;
# 108 -> 109 ;
# 110 [label="revol.util <= 25.8\ngini = 0.32\nsamples = 5\nvalue = [4, 1]", fillcolor="#e58139bf"] ;
# 109 -> 110 ;
# 111 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 110 -> 111 ;
# 112 [label="gini = 0.0\nsamples = 4\nvalue = [4, 0]", fillcolor="#e58139ff"] ;
# 110 -> 112 ;
# 113 [label="gini = 0.0\nsamples = 11\nvalue = [11, 0]", fillcolor="#e58139ff"] ;
# 109 -> 113 ;
# 114 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 108 -> 114 ;
# 115 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]", fillcolor="#399de5ff"] ;
# 101 -> 115 ;
# 116 [label="int.rate <= 0.1292\ngini = 0.32\nsamples = 5\nvalue = [1, 4]", fillcolor="#399de5bf"] ;
# 90 -> 116 ;
# 117 [label="gini = 0.0\nsamples = 4\nvalue = [0, 4]", fillcolor="#399de5ff"] ;
# 116 -> 117 ;
# 118 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]", fillcolor="#e58139ff"] ;
# 116 -> 118 ;
# 119 [label="installment <= 324.65\ngini = 0.2008\nsamples = 53\nvalue = [47, 6]", fillcolor="#e58139de"] ;
# 89 -> 119 ;
# 120 [label="fico <= 734.5\ngini = 0.0887\nsamples = 43\nvalue = [41, 2]", fillcolor="#e58139f3"] ;
# 119 -> 120 ;
# 121 [label="revol.bal <= 133762.0\ngini = 0.0465\nsamples = 42\nvalue = [41, 1]", fillcolor="#e58139f9"] ;
# 120 -> 121 ;
# 122 [label="gini = 0.0\nsamples = 40\nvalue = [40, 0]", fillcolor="#e58139ff"] ;
# 121 -> 122 ;
# 123 [label="pub.rec <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]", fillcolor="#e5813900"] ;
# 121 -> 123 ;
# 124 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]", fillcolor="#e58139ff"] ;
# 123 -> 124 ;
# 125 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 123 -> 125 ;
# 126 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 120 -> 126 ;
# 127 [label="revol.bal <= 7953.0\ngini = 0.48\nsamples = 10\nvalue = [6, 4]", fillcolor="#e5813955"] ;
# 119 -> 127 ;
# 128 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]", fillcolor="#399de5ff"] ;
# 127 -> 128 ;
# 129 [label="int.rate <= 0.114\ngini = 0.2449\nsamples = 7\nvalue = [6, 1]", fillcolor="#e58139d4"] ;
# 127 -> 129 ;
# 130 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 129 -> 130 ;
# 131 [label="gini = 0.0\nsamples = 6\nvalue = [6, 0]", fillcolor="#e58139ff"] ;
# 129 -> 131 ;
# 132 [label="days.with.cr.line <= 5342.0\ngini = 0.3931\nsamples = 439\nvalue = [321, 118]", fillcolor="#e58139a1"] ;
# 6 -> 132 ;
# 133 [label="days.with.cr.line <= 4814.9795\ngini = 0.367\nsamples = 351\nvalue = [266, 85]", fillcolor="#e58139ae"] ;
# 132 -> 133 ;
# 134 [label="dti <= 2.295\ngini = 0.3872\nsamples = 320\nvalue = [236, 84]", fillcolor="#e58139a4"] ;
# 133 -> 134 ;
# 135 [label="revol.bal <= 918.0\ngini = 0.4861\nsamples = 12\nvalue = [5, 7]", fillcolor="#399de549"] ;
# 134 -> 135 ;
# 136 [label="gini = 0.0\nsamples = 5\nvalue = [0, 5]", fillcolor="#399de5ff"] ;
# 135 -> 136 ;
# 137 [label="purpose_debt_consolidation <= 0.5\ngini = 0.4082\nsamples = 7\nvalue = [5, 2]", fillcolor="#e5813999"] ;
# 135 -> 137 ;
# 138 [label="gini = 0.0\nsamples = 4\nvalue = [4, 0]", fillcolor="#e58139ff"] ;
# 137 -> 138 ;
# 139 [label="dti <= 2.18\ngini = 0.4444\nsamples = 3\nvalue = [1, 2]", fillcolor="#399de57f"] ;
# 137 -> 139 ;
# 140 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]", fillcolor="#399de5ff"] ;
# 139 -> 140 ;
# 141 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]", fillcolor="#e58139ff"] ;
# 139 -> 141 ;
# 142 [label="days.with.cr.line <= 2805.021\ngini = 0.375\nsamples = 308\nvalue = [231, 77]", fillcolor="#e58139aa"] ;
# 134 -> 142 ;
# 143 [label="int.rate <= 0.1856\ngini = 0.2991\nsamples = 142\nvalue = [116, 26]", fillcolor="#e58139c6"] ;
# 142 -> 143 ;
# 144 [label="fico <= 634.5\ngini = 0.2841\nsamples = 140\nvalue = [116, 24]", fillcolor="#e58139ca"] ;
# 143 -> 144 ;
# 145 [label="revol.util <= 101.5\ngini = 0.4444\nsamples = 3\nvalue = [1, 2]", fillcolor="#399de57f"] ;
# 144 -> 145 ;
# 146 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]", fillcolor="#399de5ff"] ;
# 145 -> 146 ;
# 147 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]", fillcolor="#e58139ff"] ;
# 145 -> 147 ;
# 148 [label="log.annual.inc <= 11.6555\ngini = 0.2696\nsamples = 137\nvalue = [115, 22]", fillcolor="#e58139ce"] ;
# 144 -> 148 ;
# 149 [label="dti <= 29.335\ngini = 0.2611\nsamples = 136\nvalue = [115, 21]", fillcolor="#e58139d0"] ;
# 148 -> 149 ;
# 150 [label="fico <= 669.5\ngini = 0.2524\nsamples = 135\nvalue = [115, 20]", fillcolor="#e58139d3"] ;
# 149 -> 150 ;
# 151 [label="installment <= 72.815\ngini = 0.3172\nsamples = 86\nvalue = [69, 17]", fillcolor="#e58139c0"] ;
# 150 -> 151 ;
# 152 [label="gini = 0.0\nsamples = 16\nvalue = [16, 0]", fillcolor="#e58139ff"] ;
# 151 -> 152 ;
# 153 [label="installment <= 106.64\ngini = 0.3678\nsamples = 70\nvalue = [53, 17]", fillcolor="#e58139ad"] ;
# 151 -> 153 ;
# 154 [label="purpose_credit_card <= 0.5\ngini = 0.375\nsamples = 8\nvalue = [2, 6]", fillcolor="#399de5aa"] ;
# 153 -> 154 ;
# 155 [label="gini = 0.0\nsamples = 5\nvalue = [0, 5]", fillcolor="#399de5ff"] ;
# 154 -> 155 ;
# 156 [label="fico <= 647.0\ngini = 0.4444\nsamples = 3\nvalue = [2, 1]", fillcolor="#e581397f"] ;
# 154 -> 156 ;
# 157 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 156 -> 157 ;
# 158 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]", fillcolor="#e58139ff"] ;
# 156 -> 158 ;
# 159 [label="days.with.cr.line <= 1729.4792\ngini = 0.2919\nsamples = 62\nvalue = [51, 11]", fillcolor="#e58139c8"] ;
# 153 -> 159 ;
# 160 [label="installment <= 160.2\ngini = 0.3967\nsamples = 33\nvalue = [24, 9]", fillcolor="#e581399f"] ;
# 159 -> 160 ;
# 161 [label="gini = 0.0\nsamples = 11\nvalue = [11, 0]", fillcolor="#e58139ff"] ;
# 160 -> 161 ;
# 162 [label="dti <= 9.19\ngini = 0.4835\nsamples = 22\nvalue = [13, 9]", fillcolor="#e581394e"] ;
# 160 -> 162 ;
# 163 [label="revol.util <= 67.05\ngini = 0.4861\nsamples = 12\nvalue = [5, 7]", fillcolor="#399de549"] ;
# 162 -> 163 ;
# 164 [label="installment <= 221.065\ngini = 0.2778\nsamples = 6\nvalue = [5, 1]", fillcolor="#e58139cc"] ;
# 163 -> 164 ;
# 165 [label="gini = 0.0\nsamples = 5\nvalue = [5, 0]", fillcolor="#e58139ff"] ;
# 164 -> 165 ;
# 166 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 164 -> 166 ;
# 167 [label="gini = 0.0\nsamples = 6\nvalue = [0, 6]", fillcolor="#399de5ff"] ;
# 163 -> 167 ;
# 168 [label="fico <= 662.0\ngini = 0.32\nsamples = 10\nvalue = [8, 2]", fillcolor="#e58139bf"] ;
# 162 -> 168 ;
# 169 [label="revol.util <= 62.2\ngini = 0.1975\nsamples = 9\nvalue = [8, 1]", fillcolor="#e58139df"] ;
# 168 -> 169 ;
# 170 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 169 -> 170 ;
# 171 [label="gini = 0.0\nsamples = 8\nvalue = [8, 0]", fillcolor="#e58139ff"] ;
# 169 -> 171 ;
# 172 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 168 -> 172 ;
# 173 [label="purpose_educational <= 0.5\ngini = 0.1284\nsamples = 29\nvalue = [27, 2]", fillcolor="#e58139ec"] ;
# 159 -> 173 ;
# 174 [label="revol.bal <= 1263.0\ngini = 0.0689\nsamples = 28\nvalue = [27, 1]", fillcolor="#e58139f6"] ;
# 173 -> 174 ;
# 175 [label="int.rate <= 0.1493\ngini = 0.4444\nsamples = 3\nvalue = [2, 1]", fillcolor="#e581397f"] ;
# 174 -> 175 ;
# 176 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]", fillcolor="#e58139ff"] ;
# 175 -> 176 ;
# 177 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 175 -> 177 ;
# 178 [label="gini = 0.0\nsamples = 25\nvalue = [25, 0]", fillcolor="#e58139ff"] ;
# 174 -> 178 ;
# 179 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 173 -> 179 ;
# 180 [label="log.annual.inc <= 8.4441\ngini = 0.115\nsamples = 49\nvalue = [46, 3]", fillcolor="#e58139ee"] ;
# 150 -> 180 ;
# 181 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 180 -> 181 ;
# 182 [label="revol.util <= 62.05\ngini = 0.0799\nsamples = 48\nvalue = [46, 2]", fillcolor="#e58139f4"] ;
# 180 -> 182 ;
# 183 [label="inq.last.6mths <= 5.5\ngini = 0.2076\nsamples = 17\nvalue = [15, 2]", fillcolor="#e58139dd"] ;
# 182 -> 183 ;
# 184 [label="installment <= 91.1\ngini = 0.1172\nsamples = 16\nvalue = [15, 1]", fillcolor="#e58139ee"] ;
# 183 -> 184 ;
# 185 [label="int.rate <= 0.1438\ngini = 0.5\nsamples = 2\nvalue = [1, 1]", fillcolor="#e5813900"] ;
# 184 -> 185 ;
# 186 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]", fillcolor="#e58139ff"] ;
# 185 -> 186 ;
# 187 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 185 -> 187 ;
# 188 [label="gini = 0.0\nsamples = 14\nvalue = [14, 0]", fillcolor="#e58139ff"] ;
# 184 -> 188 ;
# 189 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 183 -> 189 ;
# 190 [label="gini = 0.0\nsamples = 31\nvalue = [31, 0]", fillcolor="#e58139ff"] ;
# 182 -> 190 ;
# 191 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 149 -> 191 ;
# 192 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 148 -> 192 ;
# 193 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]", fillcolor="#399de5ff"] ;
# 143 -> 193 ;
# 194 [label="log.annual.inc <= 9.8508\ngini = 0.4257\nsamples = 166\nvalue = [115, 51]", fillcolor="#e581398e"] ;
# 142 -> 194 ;
# 195 [label="gini = 0.0\nsamples = 5\nvalue = [0, 5]", fillcolor="#399de5ff"] ;
# 194 -> 195 ;
# 196 [label="inq.last.6mths <= 5.5\ngini = 0.4082\nsamples = 161\nvalue = [115, 46]", fillcolor="#e5813999"] ;
# 194 -> 196 ;
# 197 [label="revol.bal <= 8842.5\ngini = 0.38\nsamples = 149\nvalue = [111, 38]", fillcolor="#e58139a8"] ;
# 196 -> 197 ;
# 198 [label="dti <= 9.09\ngini = 0.474\nsamples = 57\nvalue = [35, 22]", fillcolor="#e581395f"] ;
# 197 -> 198 ;
# 199 [label="purpose_major_purchase <= 0.5\ngini = 0.1327\nsamples = 14\nvalue = [13, 1]", fillcolor="#e58139eb"] ;
# 198 -> 199 ;
# 200 [label="gini = 0.0\nsamples = 13\nvalue = [13, 0]", fillcolor="#e58139ff"] ;
# 199 -> 200 ;
# 201 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 199 -> 201 ;
# 202 [label="log.annual.inc <= 10.8918\ngini = 0.4997\nsamples = 43\nvalue = [22, 21]", fillcolor="#e581390c"] ;
# 198 -> 202 ;
# 203 [label="revol.bal <= 4056.5\ngini = 0.48\nsamples = 35\nvalue = [21, 14]", fillcolor="#e5813955"] ;
# 202 -> 203 ;
# 204 [label="gini = 0.0\nsamples = 9\nvalue = [9, 0]", fillcolor="#e58139ff"] ;
# 203 -> 204 ;
# 205 [label="log.annual.inc <= 10.6805\ngini = 0.497\nsamples = 26\nvalue = [12, 14]", fillcolor="#399de524"] ;
# 203 -> 205 ;
# 206 [label="fico <= 659.5\ngini = 0.375\nsamples = 16\nvalue = [4, 12]", fillcolor="#399de5aa"] ;
# 205 -> 206 ;
# 207 [label="installment <= 253.585\ngini = 0.1653\nsamples = 11\nvalue = [1, 10]", fillcolor="#399de5e6"] ;
# 206 -> 207 ;
# 208 [label="gini = 0.0\nsamples = 10\nvalue = [0, 10]", fillcolor="#399de5ff"] ;
# 207 -> 208 ;
# 209 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]", fillcolor="#e58139ff"] ;
# 207 -> 209 ;
# 210 [label="int.rate <= 0.1331\ngini = 0.48\nsamples = 5\nvalue = [3, 2]", fillcolor="#e5813955"] ;
# 206 -> 210 ;
# 211 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]", fillcolor="#399de5ff"] ;
# 210 -> 211 ;
# 212 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]", fillcolor="#e58139ff"] ;
# 210 -> 212 ;
# 213 [label="days.with.cr.line <= 4559.9795\ngini = 0.32\nsamples = 10\nvalue = [8, 2]", fillcolor="#e58139bf"] ;
# 205 -> 213 ;
# 214 [label="gini = 0.0\nsamples = 7\nvalue = [7, 0]", fillcolor="#e58139ff"] ;
# 213 -> 214 ;
# 215 [label="dti <= 21.785\ngini = 0.4444\nsamples = 3\nvalue = [1, 2]", fillcolor="#399de57f"] ;
# 213 -> 215 ;
# 216 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]", fillcolor="#399de5ff"] ;
# 215 -> 216 ;
# 217 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]", fillcolor="#e58139ff"] ;
# 215 -> 217 ;
# 218 [label="revol.bal <= 447.0\ngini = 0.2188\nsamples = 8\nvalue = [1, 7]", fillcolor="#399de5db"] ;
# 202 -> 218 ;
# 219 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]", fillcolor="#e58139ff"] ;
# 218 -> 219 ;
# 220 [label="gini = 0.0\nsamples = 7\nvalue = [0, 7]", fillcolor="#399de5ff"] ;
# 218 -> 220 ;
# 221 [label="log.annual.inc <= 11.3677\ngini = 0.2873\nsamples = 92\nvalue = [76, 16]", fillcolor="#e58139c9"] ;
# 197 -> 221 ;
# 222 [label="int.rate <= 0.1643\ngini = 0.1871\nsamples = 67\nvalue = [60, 7]", fillcolor="#e58139e1"] ;
# 221 -> 222 ;
# 223 [label="installment <= 335.79\ngini = 0.1264\nsamples = 59\nvalue = [55, 4]", fillcolor="#e58139ec"] ;
# 222 -> 223 ;
# 224 [label="dti <= 7.455\ngini = 0.0754\nsamples = 51\nvalue = [49, 2]", fillcolor="#e58139f5"] ;
# 223 -> 224 ;
# 225 [label="days.with.cr.line <= 3945.0\ngini = 0.4444\nsamples = 3\nvalue = [2, 1]", fillcolor="#e581397f"] ;
# 224 -> 225 ;
# 226 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]", fillcolor="#e58139ff"] ;
# 225 -> 226 ;
# 227 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 225 -> 227 ;
# 228 [label="revol.util <= 57.5\ngini = 0.0408\nsamples = 48\nvalue = [47, 1]", fillcolor="#e58139fa"] ;
# 224 -> 228 ;
# 229 [label="inq.last.6mths <= 3.5\ngini = 0.4444\nsamples = 3\nvalue = [2, 1]", fillcolor="#e581397f"] ;
# 228 -> 229 ;
# 230 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]", fillcolor="#e58139ff"] ;
# 229 -> 230 ;
# 231 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 229 -> 231 ;
# 232 [label="gini = 0.0\nsamples = 45\nvalue = [45, 0]", fillcolor="#e58139ff"] ;
# 228 -> 232 ;
# 233 [label="int.rate <= 0.1332\ngini = 0.375\nsamples = 8\nvalue = [6, 2]", fillcolor="#e58139aa"] ;
# 223 -> 233 ;
# 234 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]", fillcolor="#399de5ff"] ;
# 233 -> 234 ;
# 235 [label="gini = 0.0\nsamples = 6\nvalue = [6, 0]", fillcolor="#e58139ff"] ;
# 233 -> 235 ;
# 236 [label="log.annual.inc <= 10.6799\ngini = 0.4688\nsamples = 8\nvalue = [5, 3]", fillcolor="#e5813966"] ;
# 222 -> 236 ;
# 237 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]", fillcolor="#399de5ff"] ;
# 236 -> 237 ;
# 238 [label="inq.last.6mths <= 0.5\ngini = 0.2778\nsamples = 6\nvalue = [5, 1]", fillcolor="#e58139cc"] ;
# 236 -> 238 ;
# 239 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 238 -> 239 ;
# 240 [label="gini = 0.0\nsamples = 5\nvalue = [5, 0]", fillcolor="#e58139ff"] ;
# 238 -> 240 ;
# 241 [label="log.annual.inc <= 11.4009\ngini = 0.4608\nsamples = 25\nvalue = [16, 9]", fillcolor="#e5813970"] ;
# 221 -> 241 ;
# 242 [label="gini = 0.0\nsamples = 4\nvalue = [0, 4]", fillcolor="#399de5ff"] ;
# 241 -> 242 ;
# 243 [label="revol.util <= 94.5\ngini = 0.3628\nsamples = 21\nvalue = [16, 5]", fillcolor="#e58139af"] ;
# 241 -> 243 ;
# 244 [label="days.with.cr.line <= 4544.9795\ngini = 0.2076\nsamples = 17\nvalue = [15, 2]", fillcolor="#e58139dd"] ;
# 243 -> 244 ;
# 245 [label="installment <= 95.92\ngini = 0.1172\nsamples = 16\nvalue = [15, 1]", fillcolor="#e58139ee"] ;
# 244 -> 245 ;
# 246 [label="days.with.cr.line <= 3989.979\ngini = 0.5\nsamples = 2\nvalue = [1, 1]", fillcolor="#e5813900"] ;
# 245 -> 246 ;
# 247 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]", fillcolor="#e58139ff"] ;
# 246 -> 247 ;
# 248 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 246 -> 248 ;
# 249 [label="gini = 0.0\nsamples = 14\nvalue = [14, 0]", fillcolor="#e58139ff"] ;
# 245 -> 249 ;
# 250 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 244 -> 250 ;
# 251 [label="dti <= 13.285\ngini = 0.375\nsamples = 4\nvalue = [1, 3]", fillcolor="#399de5aa"] ;
# 243 -> 251 ;
# 252 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]", fillcolor="#399de5ff"] ;
# 251 -> 252 ;
# 253 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]", fillcolor="#e58139ff"] ;
# 251 -> 253 ;
# 254 [label="dti <= 18.345\ngini = 0.4444\nsamples = 12\nvalue = [4, 8]", fillcolor="#399de57f"] ;
# 196 -> 254 ;
# 255 [label="gini = 0.0\nsamples = 6\nvalue = [0, 6]", fillcolor="#399de5ff"] ;
# 254 -> 255 ;
# 256 [label="purpose_debt_consolidation <= 0.5\ngini = 0.4444\nsamples = 6\nvalue = [4, 2]", fillcolor="#e581397f"] ;
# 254 -> 256 ;
# 257 [label="installment <= 216.975\ngini = 0.4444\nsamples = 3\nvalue = [1, 2]", fillcolor="#399de57f"] ;
# 256 -> 257 ;
# 258 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]", fillcolor="#e58139ff"] ;
# 257 -> 258 ;
# 259 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]", fillcolor="#399de5ff"] ;
# 257 -> 259 ;
# 260 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]", fillcolor="#e58139ff"] ;
# 256 -> 260 ;
# 261 [label="inq.last.6mths <= 4.5\ngini = 0.0624\nsamples = 31\nvalue = [30, 1]", fillcolor="#e58139f6"] ;
# 133 -> 261 ;
# 262 [label="gini = 0.0\nsamples = 25\nvalue = [25, 0]", fillcolor="#e58139ff"] ;
# 261 -> 262 ;
# 263 [label="log.annual.inc <= 10.8685\ngini = 0.2778\nsamples = 6\nvalue = [5, 1]", fillcolor="#e58139cc"] ;
# 261 -> 263 ;
# 264 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 263 -> 264 ;
# 265 [label="gini = 0.0\nsamples = 5\nvalue = [5, 0]", fillcolor="#e58139ff"] ;
# 263 -> 265 ;
# 266 [label="days.with.cr.line <= 5579.5\ngini = 0.4688\nsamples = 88\nvalue = [55, 33]", fillcolor="#e5813966"] ;
# 132 -> 266 ;
# 267 [label="gini = 0.0\nsamples = 7\nvalue = [0, 7]", fillcolor="#399de5ff"] ;
# 266 -> 267 ;
# 268 [label="revol.util <= 57.15\ngini = 0.4359\nsamples = 81\nvalue = [55, 26]", fillcolor="#e5813986"] ;
# 266 -> 268 ;
# 269 [label="dti <= 11.02\ngini = 0.2778\nsamples = 6\nvalue = [1, 5]", fillcolor="#399de5cc"] ;
# 268 -> 269 ;
# 270 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]", fillcolor="#e58139ff"] ;
# 269 -> 270 ;
# 271 [label="gini = 0.0\nsamples = 5\nvalue = [0, 5]", fillcolor="#399de5ff"] ;
# 269 -> 271 ;
# 272 [label="revol.util <= 80.25\ngini = 0.4032\nsamples = 75\nvalue = [54, 21]", fillcolor="#e581399c"] ;
# 268 -> 272 ;
# 273 [label="installment <= 137.93\ngini = 0.2337\nsamples = 37\nvalue = [32, 5]", fillcolor="#e58139d7"] ;
# 272 -> 273 ;
# 274 [label="revol.util <= 69.3\ngini = 0.48\nsamples = 10\nvalue = [6, 4]", fillcolor="#e5813955"] ;
# 273 -> 274 ;
# 275 [label="installment <= 86.445\ngini = 0.4444\nsamples = 6\nvalue = [2, 4]", fillcolor="#399de57f"] ;
# 274 -> 275 ;
# 276 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]", fillcolor="#e58139ff"] ;
# 275 -> 276 ;
# 277 [label="gini = 0.0\nsamples = 4\nvalue = [0, 4]", fillcolor="#399de5ff"] ;
# 275 -> 277 ;
# 278 [label="gini = 0.0\nsamples = 4\nvalue = [4, 0]", fillcolor="#e58139ff"] ;
# 274 -> 278 ;
# 279 [label="revol.util <= 60.3\ngini = 0.0713\nsamples = 27\nvalue = [26, 1]", fillcolor="#e58139f5"] ;
# 273 -> 279 ;
# 280 [label="revol.util <= 59.15\ngini = 0.32\nsamples = 5\nvalue = [4, 1]", fillcolor="#e58139bf"] ;
# 279 -> 280 ;
# 281 [label="gini = 0.0\nsamples = 4\nvalue = [4, 0]", fillcolor="#e58139ff"] ;
# 280 -> 281 ;
# 282 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 280 -> 282 ;
# 283 [label="gini = 0.0\nsamples = 22\nvalue = [22, 0]", fillcolor="#e58139ff"] ;
# 279 -> 283 ;
# 284 [label="installment <= 121.115\ngini = 0.4875\nsamples = 38\nvalue = [22, 16]", fillcolor="#e5813946"] ;
# 272 -> 284 ;
# 285 [label="gini = 0.0\nsamples = 6\nvalue = [6, 0]", fillcolor="#e58139ff"] ;
# 284 -> 285 ;
# 286 [label="dti <= 17.185\ngini = 0.5\nsamples = 32\nvalue = [16, 16]", fillcolor="#e5813900"] ;
# 284 -> 286 ;
# 287 [label="log.annual.inc <= 11.6696\ngini = 0.355\nsamples = 13\nvalue = [10, 3]", fillcolor="#e58139b3"] ;
# 286 -> 287 ;
# 288 [label="gini = 0.0\nsamples = 9\nvalue = [9, 0]", fillcolor="#e58139ff"] ;
# 287 -> 288 ;
# 289 [label="revol.util <= 92.65\ngini = 0.375\nsamples = 4\nvalue = [1, 3]", fillcolor="#399de5aa"] ;
# 287 -> 289 ;
# 290 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]", fillcolor="#399de5ff"] ;
# 289 -> 290 ;
# 291 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]", fillcolor="#e58139ff"] ;
# 289 -> 291 ;
# 292 [label="delinq.2yrs <= 0.5\ngini = 0.4321\nsamples = 19\nvalue = [6, 13]", fillcolor="#399de589"] ;
# 286 -> 292 ;
# 293 [label="days.with.cr.line <= 6104.4795\ngini = 0.3047\nsamples = 16\nvalue = [3, 13]", fillcolor="#399de5c4"] ;
# 292 -> 293 ;
# 294 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]", fillcolor="#e58139ff"] ;
# 293 -> 294 ;
# 295 [label="fico <= 709.5\ngini = 0.1327\nsamples = 14\nvalue = [1, 13]", fillcolor="#399de5eb"] ;
# 293 -> 295 ;
# 296 [label="gini = 0.0\nsamples = 12\nvalue = [0, 12]", fillcolor="#399de5ff"] ;
# 295 -> 296 ;
# 297 [label="revol.util <= 89.25\ngini = 0.5\nsamples = 2\nvalue = [1, 1]", fillcolor="#e5813900"] ;
# 295 -> 297 ;
# 298 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 297 -> 298 ;
# 299 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]", fillcolor="#e58139ff"] ;
# 297 -> 299 ;
# 300 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]", fillcolor="#e58139ff"] ;
# 292 -> 300 ;
# 301 [label="installment <= 240.71\ngini = 0.4989\nsamples = 21\nvalue = [11, 10]", fillcolor="#e5813917"] ;
# 5 -> 301 ;
# 302 [label="int.rate <= 0.1267\ngini = 0.32\nsamples = 10\nvalue = [8, 2]", fillcolor="#e58139bf"] ;
# 301 -> 302 ;
# 303 [label="revol.util <= 79.8\ngini = 0.4444\nsamples = 3\nvalue = [1, 2]", fillcolor="#399de57f"] ;
# 302 -> 303 ;
# 304 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]", fillcolor="#399de5ff"] ;
# 303 -> 304 ;
# 305 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]", fillcolor="#e58139ff"] ;
# 303 -> 305 ;
# 306 [label="gini = 0.0\nsamples = 7\nvalue = [7, 0]", fillcolor="#e58139ff"] ;
# 302 -> 306 ;
# 307 [label="fico <= 714.5\ngini = 0.3967\nsamples = 11\nvalue = [3, 8]", fillcolor="#399de59f"] ;
# 301 -> 307 ;
# 308 [label="installment <= 329.0\ngini = 0.1975\nsamples = 9\nvalue = [1, 8]", fillcolor="#399de5df"] ;
# 307 -> 308 ;
# 309 [label="gini = 0.0\nsamples = 8\nvalue = [0, 8]", fillcolor="#399de5ff"] ;
# 308 -> 309 ;
# 310 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]", fillcolor="#e58139ff"] ;
# 308 -> 310 ;
# 311 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]", fillcolor="#e58139ff"] ;
# 307 -> 311 ;
# 312 [label="int.rate <= 0.1603\ngini = 0.4647\nsamples = 128\nvalue = [81, 47]", fillcolor="#e581396b"] ;
# 2 -> 312 ;
# 313 [label="int.rate <= 0.1534\ngini = 0.4964\nsamples = 94\nvalue = [51, 43]", fillcolor="#e5813928"] ;
# 312 -> 313 ;
# 314 [label="days.with.cr.line <= 6373.9795\ngini = 0.4893\nsamples = 89\nvalue = [51, 38]", fillcolor="#e5813941"] ;
# 313 -> 314 ;
# 315 [label="days.with.cr.line <= 1125.0208\ngini = 0.4696\nsamples = 77\nvalue = [48, 29]", fillcolor="#e5813965"] ;
# 314 -> 315 ;
# 316 [label="revol.util <= 21.55\ngini = 0.4082\nsamples = 7\nvalue = [2, 5]", fillcolor="#399de599"] ;
# 315 -> 316 ;
# 317 [label="dti <= 1.905\ngini = 0.4444\nsamples = 3\nvalue = [2, 1]", fillcolor="#e581397f"] ;
# 316 -> 317 ;
# 318 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 317 -> 318 ;
# 319 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]", fillcolor="#e58139ff"] ;
# 317 -> 319 ;
# 320 [label="gini = 0.0\nsamples = 4\nvalue = [0, 4]", fillcolor="#399de5ff"] ;
# 316 -> 320 ;
# 321 [label="installment <= 259.77\ngini = 0.4506\nsamples = 70\nvalue = [46, 24]", fillcolor="#e581397a"] ;
# 315 -> 321 ;
# 322 [label="installment <= 171.59\ngini = 0.4856\nsamples = 53\nvalue = [31, 22]", fillcolor="#e581394a"] ;
# 321 -> 322 ;
# 323 [label="revol.bal <= 38.5\ngini = 0.4152\nsamples = 34\nvalue = [24, 10]", fillcolor="#e5813995"] ;
# 322 -> 323 ;
# 324 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]", fillcolor="#399de5ff"] ;
# 323 -> 324 ;
# 325 [label="delinq.2yrs <= 1.5\ngini = 0.3496\nsamples = 31\nvalue = [24, 7]", fillcolor="#e58139b5"] ;
# 323 -> 325 ;
# 326 [label="purpose_debt_consolidation <= 0.5\ngini = 0.2854\nsamples = 29\nvalue = [24, 5]", fillcolor="#e58139ca"] ;
# 325 -> 326 ;
# 327 [label="delinq.2yrs <= 0.5\ngini = 0.0907\nsamples = 21\nvalue = [20, 1]", fillcolor="#e58139f2"] ;
# 326 -> 327 ;
# 328 [label="gini = 0.0\nsamples = 19\nvalue = [19, 0]", fillcolor="#e58139ff"] ;
# 327 -> 328 ;
# 329 [label="revol.bal <= 2793.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]", fillcolor="#e5813900"] ;
# 327 -> 329 ;
# 330 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]", fillcolor="#e58139ff"] ;
# 329 -> 330 ;
# 331 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 329 -> 331 ;
# 332 [label="days.with.cr.line <= 3209.5417\ngini = 0.5\nsamples = 8\nvalue = [4, 4]", fillcolor="#e5813900"] ;
# 326 -> 332 ;
# 333 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]", fillcolor="#e58139ff"] ;
# 332 -> 333 ;
# 334 [label="pub.rec <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]", fillcolor="#399de5bf"] ;
# 332 -> 334 ;
# 335 [label="gini = 0.0\nsamples = 4\nvalue = [0, 4]", fillcolor="#399de5ff"] ;
# 334 -> 335 ;
# 336 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]", fillcolor="#e58139ff"] ;
# 334 -> 336 ;
# 337 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]", fillcolor="#399de5ff"] ;
# 325 -> 337 ;
# 338 [label="fico <= 694.5\ngini = 0.4654\nsamples = 19\nvalue = [7, 12]", fillcolor="#399de56a"] ;
# 322 -> 338 ;
# 339 [label="revol.util <= 36.85\ngini = 0.355\nsamples = 13\nvalue = [3, 10]", fillcolor="#399de5b3"] ;
# 338 -> 339 ;
# 340 [label="inq.last.6mths <= 14.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]", fillcolor="#e5813900"] ;
# 339 -> 340 ;
# 341 [label="days.with.cr.line <= 4005.021\ngini = 0.375\nsamples = 4\nvalue = [1, 3]", fillcolor="#399de5aa"] ;
# 340 -> 341 ;
# 342 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]", fillcolor="#399de5ff"] ;
# 341 -> 342 ;
# 343 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]", fillcolor="#e58139ff"] ;
# 341 -> 343 ;
# 344 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]", fillcolor="#e58139ff"] ;
# 340 -> 344 ;
# 345 [label="gini = 0.0\nsamples = 7\nvalue = [0, 7]", fillcolor="#399de5ff"] ;
# 339 -> 345 ;
# 346 [label="int.rate <= 0.1256\ngini = 0.4444\nsamples = 6\nvalue = [4, 2]", fillcolor="#e581397f"] ;
# 338 -> 346 ;
# 347 [label="days.with.cr.line <= 5204.9795\ngini = 0.4444\nsamples = 3\nvalue = [1, 2]", fillcolor="#399de57f"] ;
# 346 -> 347 ;
# 348 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]", fillcolor="#399de5ff"] ;
# 347 -> 348 ;
# 349 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]", fillcolor="#e58139ff"] ;
# 347 -> 349 ;
# 350 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]", fillcolor="#e58139ff"] ;
# 346 -> 350 ;
# 351 [label="revol.bal <= 29383.5\ngini = 0.2076\nsamples = 17\nvalue = [15, 2]", fillcolor="#e58139dd"] ;
# 321 -> 351 ;
# 352 [label="revol.bal <= 1545.5\ngini = 0.1172\nsamples = 16\nvalue = [15, 1]", fillcolor="#e58139ee"] ;
# 351 -> 352 ;
# 353 [label="revol.bal <= 1111.5\ngini = 0.4444\nsamples = 3\nvalue = [2, 1]", fillcolor="#e581397f"] ;
# 352 -> 353 ;
# 354 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]", fillcolor="#e58139ff"] ;
# 353 -> 354 ;
# 355 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 353 -> 355 ;
# 356 [label="gini = 0.0\nsamples = 13\nvalue = [13, 0]", fillcolor="#e58139ff"] ;
# 352 -> 356 ;
# 357 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 351 -> 357 ;
# 358 [label="fico <= 679.5\ngini = 0.375\nsamples = 12\nvalue = [3, 9]", fillcolor="#399de5aa"] ;
# 314 -> 358 ;
# 359 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]", fillcolor="#e58139ff"] ;
# 358 -> 359 ;
# 360 [label="gini = 0.0\nsamples = 9\nvalue = [0, 9]", fillcolor="#399de5ff"] ;
# 358 -> 360 ;
# 361 [label="gini = 0.0\nsamples = 5\nvalue = [0, 5]", fillcolor="#399de5ff"] ;
# 313 -> 361 ;
# 362 [label="purpose_educational <= 0.5\ngini = 0.2076\nsamples = 34\nvalue = [30, 4]", fillcolor="#e58139dd"] ;
# 312 -> 362 ;
# 363 [label="fico <= 659.5\ngini = 0.1653\nsamples = 33\nvalue = [30, 3]", fillcolor="#e58139e6"] ;
# 362 -> 363 ;
# 364 [label="revol.bal <= 14909.5\ngini = 0.4444\nsamples = 6\nvalue = [4, 2]", fillcolor="#e581397f"] ;
# 363 -> 364 ;
# 365 [label="gini = 0.0\nsamples = 4\nvalue = [4, 0]", fillcolor="#e58139ff"] ;
# 364 -> 365 ;
# 366 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]", fillcolor="#399de5ff"] ;
# 364 -> 366 ;
# 367 [label="fico <= 669.5\ngini = 0.0713\nsamples = 27\nvalue = [26, 1]", fillcolor="#e58139f5"] ;
# 363 -> 367 ;
# 368 [label="inq.last.6mths <= 8.5\ngini = 0.1975\nsamples = 9\nvalue = [8, 1]", fillcolor="#e58139df"] ;
# 367 -> 368 ;
# 369 [label="gini = 0.0\nsamples = 7\nvalue = [7, 0]", fillcolor="#e58139ff"] ;
# 368 -> 369 ;
# 370 [label="dti <= 19.65\ngini = 0.5\nsamples = 2\nvalue = [1, 1]", fillcolor="#e5813900"] ;
# 368 -> 370 ;
# 371 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 370 -> 371 ;
# 372 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]", fillcolor="#e58139ff"] ;
# 370 -> 372 ;
# 373 [label="gini = 0.0\nsamples = 18\nvalue = [18, 0]", fillcolor="#e58139ff"] ;
# 367 -> 373 ;
# 374 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 362 -> 374 ;
# 375 [label="log.annual.inc <= 10.3812\ngini = 0.4643\nsamples = 374\nvalue = [237, 137]", fillcolor="#e581396c"] ;
# 1 -> 375 ;
# 376 [label="inq.last.6mths <= 0.5\ngini = 0.2907\nsamples = 17\nvalue = [3, 14]", fillcolor="#399de5c8"] ;
# 375 -> 376 ;
# 377 [label="installment <= 358.89\ngini = 0.4444\nsamples = 3\nvalue = [2, 1]", fillcolor="#e581397f"] ;
# 376 -> 377 ;
# 378 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 377 -> 378 ;
# 379 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]", fillcolor="#e58139ff"] ;
# 377 -> 379 ;
# 380 [label="revol.util <= 88.15\ngini = 0.1327\nsamples = 14\nvalue = [1, 13]", fillcolor="#399de5eb"] ;
# 376 -> 380 ;
# 381 [label="gini = 0.0\nsamples = 13\nvalue = [0, 13]", fillcolor="#399de5ff"] ;
# 380 -> 381 ;
# 382 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]", fillcolor="#e58139ff"] ;
# 380 -> 382 ;
# 383 [label="int.rate <= 0.174\ngini = 0.4517\nsamples = 357\nvalue = [234, 123]", fillcolor="#e5813979"] ;
# 375 -> 383 ;
# 384 [label="revol.bal <= 387190.5\ngini = 0.4273\nsamples = 291\nvalue = [201, 90]", fillcolor="#e581398d"] ;
# 383 -> 384 ;
# 385 [label="days.with.cr.line <= 7634.9795\ngini = 0.4197\nsamples = 287\nvalue = [201, 86]", fillcolor="#e5813992"] ;
# 384 -> 385 ;
# 386 [label="revol.util <= 97.15\ngini = 0.4435\nsamples = 247\nvalue = [165, 82]", fillcolor="#e5813980"] ;
# 385 -> 386 ;
# 387 [label="dti <= 1.475\ngini = 0.4348\nsamples = 241\nvalue = [164, 77]", fillcolor="#e5813987"] ;
# 386 -> 387 ;
# 388 [label="gini = 0.0\nsamples = 12\nvalue = [12, 0]", fillcolor="#e58139ff"] ;
# 387 -> 388 ;
# 389 [label="installment <= 702.335\ngini = 0.4464\nsamples = 229\nvalue = [152, 77]", fillcolor="#e581397e"] ;
# 387 -> 389 ;
# 390 [label="installment <= 352.565\ngini = 0.4187\nsamples = 191\nvalue = [134, 57]", fillcolor="#e5813993"] ;
# 389 -> 390 ;
# 391 [label="fico <= 697.0\ngini = 0.2778\nsamples = 6\nvalue = [1, 5]", fillcolor="#399de5cc"] ;
# 390 -> 391 ;
# 392 [label="gini = 0.0\nsamples = 5\nvalue = [0, 5]", fillcolor="#399de5ff"] ;
# 391 -> 392 ;
# 393 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]", fillcolor="#e58139ff"] ;
# 391 -> 393 ;
# 394 [label="log.annual.inc <= 11.0185\ngini = 0.4041\nsamples = 185\nvalue = [133, 52]", fillcolor="#e581399b"] ;
# 390 -> 394 ;
# 395 [label="log.annual.inc <= 10.9937\ngini = 0.4787\nsamples = 63\nvalue = [38, 25]", fillcolor="#e5813957"] ;
# 394 -> 395 ;
# 396 [label="revol.util <= 55.75\ngini = 0.4444\nsamples = 57\nvalue = [38, 19]", fillcolor="#e581397f"] ;
# 395 -> 396 ;
# 397 [label="revol.util <= 25.25\ngini = 0.4993\nsamples = 27\nvalue = [13, 14]", fillcolor="#399de512"] ;
# 396 -> 397 ;
# 398 [label="gini = 0.0\nsamples = 4\nvalue = [4, 0]", fillcolor="#e58139ff"] ;
# 397 -> 398 ;
# 399 [label="fico <= 719.5\ngini = 0.4764\nsamples = 23\nvalue = [9, 14]", fillcolor="#399de55b"] ;
# 397 -> 399 ;
# 400 [label="revol.bal <= 9599.0\ngini = 0.4444\nsamples = 21\nvalue = [7, 14]", fillcolor="#399de57f"] ;
# 399 -> 400 ;
# 401 [label="purpose_debt_consolidation <= 0.5\ngini = 0.4938\nsamples = 9\nvalue = [5, 4]", fillcolor="#e5813933"] ;
# 400 -> 401 ;
# 402 [label="int.rate <= 0.1339\ngini = 0.32\nsamples = 5\nvalue = [1, 4]", fillcolor="#399de5bf"] ;
# 401 -> 402 ;
# 403 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]", fillcolor="#e58139ff"] ;
# 402 -> 403 ;
# 404 [label="gini = 0.0\nsamples = 4\nvalue = [0, 4]", fillcolor="#399de5ff"] ;
# 402 -> 404 ;
# 405 [label="gini = 0.0\nsamples = 4\nvalue = [4, 0]", fillcolor="#e58139ff"] ;
# 401 -> 405 ;
# 406 [label="log.annual.inc <= 10.4772\ngini = 0.2778\nsamples = 12\nvalue = [2, 10]", fillcolor="#399de5cc"] ;
# 400 -> 406 ;
# 407 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]", fillcolor="#e58139ff"] ;
# 406 -> 407 ;
# 408 [label="log.annual.inc <= 10.944\ngini = 0.1653\nsamples = 11\nvalue = [1, 10]", fillcolor="#399de5e6"] ;
# 406 -> 408 ;
# 409 [label="gini = 0.0\nsamples = 10\nvalue = [0, 10]", fillcolor="#399de5ff"] ;
# 408 -> 409 ;
# 410 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]", fillcolor="#e58139ff"] ;
# 408 -> 410 ;
# 411 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]", fillcolor="#e58139ff"] ;
# 399 -> 411 ;
# 412 [label="days.with.cr.line <= 1769.9584\ngini = 0.2778\nsamples = 30\nvalue = [25, 5]", fillcolor="#e58139cc"] ;
# 396 -> 412 ;
# 413 [label="int.rate <= 0.1276\ngini = 0.32\nsamples = 5\nvalue = [1, 4]", fillcolor="#399de5bf"] ;
# 412 -> 413 ;
# 414 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]", fillcolor="#e58139ff"] ;
# 413 -> 414 ;
# 415 [label="gini = 0.0\nsamples = 4\nvalue = [0, 4]", fillcolor="#399de5ff"] ;
# 413 -> 415 ;
# 416 [label="purpose_credit_card <= 0.5\ngini = 0.0768\nsamples = 25\nvalue = [24, 1]", fillcolor="#e58139f4"] ;
# 412 -> 416 ;
# 417 [label="gini = 0.0\nsamples = 23\nvalue = [23, 0]", fillcolor="#e58139ff"] ;
# 416 -> 417 ;
# 418 [label="revol.util <= 66.25\ngini = 0.5\nsamples = 2\nvalue = [1, 1]", fillcolor="#e5813900"] ;
# 416 -> 418 ;
# 419 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 418 -> 419 ;
# 420 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]", fillcolor="#e58139ff"] ;
# 418 -> 420 ;
# 421 [label="gini = 0.0\nsamples = 6\nvalue = [0, 6]", fillcolor="#399de5ff"] ;
# 395 -> 421 ;
# 422 [label="days.with.cr.line <= 6810.0415\ngini = 0.3447\nsamples = 122\nvalue = [95, 27]", fillcolor="#e58139b7"] ;
# 394 -> 422 ;
# 423 [label="revol.util <= 1.3\ngini = 0.2996\nsamples = 109\nvalue = [89, 20]", fillcolor="#e58139c6"] ;
# 422 -> 423 ;
# 424 [label="purpose_debt_consolidation <= 0.5\ngini = 0.4444\nsamples = 3\nvalue = [1, 2]", fillcolor="#399de57f"] ;
# 423 -> 424 ;
# 425 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]", fillcolor="#399de5ff"] ;
# 424 -> 425 ;
# 426 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]", fillcolor="#e58139ff"] ;
# 424 -> 426 ;
# 427 [label="fico <= 684.5\ngini = 0.282\nsamples = 106\nvalue = [88, 18]", fillcolor="#e58139cb"] ;
# 423 -> 427 ;
# 428 [label="purpose_small_business <= 0.5\ngini = 0.414\nsamples = 41\nvalue = [29, 12]", fillcolor="#e5813995"] ;
# 427 -> 428 ;
# 429 [label="installment <= 521.415\ngini = 0.3813\nsamples = 39\nvalue = [29, 10]", fillcolor="#e58139a7"] ;
# 428 -> 429 ;
# 430 [label="inq.last.6mths <= 13.0\ngini = 0.2188\nsamples = 24\nvalue = [21, 3]", fillcolor="#e58139db"] ;
# 429 -> 430 ;
# 431 [label="pub.rec <= 0.5\ngini = 0.1588\nsamples = 23\nvalue = [21, 2]", fillcolor="#e58139e7"] ;
# 430 -> 431 ;
# 432 [label="installment <= 484.495\ngini = 0.0907\nsamples = 21\nvalue = [20, 1]", fillcolor="#e58139f2"] ;
# 431 -> 432 ;
# 433 [label="gini = 0.0\nsamples = 15\nvalue = [15, 0]", fillcolor="#e58139ff"] ;
# 432 -> 433 ;
# 434 [label="installment <= 496.785\ngini = 0.2778\nsamples = 6\nvalue = [5, 1]", fillcolor="#e58139cc"] ;
# 432 -> 434 ;
# 435 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 434 -> 435 ;
# 436 [label="gini = 0.0\nsamples = 5\nvalue = [5, 0]", fillcolor="#e58139ff"] ;
# 434 -> 436 ;
# 437 [label="fico <= 674.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]", fillcolor="#e5813900"] ;
# 431 -> 437 ;
# 438 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 437 -> 438 ;
# 439 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]", fillcolor="#e58139ff"] ;
# 437 -> 439 ;
# 440 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 430 -> 440 ;
# 441 [label="int.rate <= 0.1504\ngini = 0.4978\nsamples = 15\nvalue = [8, 7]", fillcolor="#e5813920"] ;
# 429 -> 441 ;
# 442 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]", fillcolor="#399de5ff"] ;
# 441 -> 442 ;
# 443 [label="delinq.2yrs <= 1.5\ngini = 0.4444\nsamples = 12\nvalue = [8, 4]", fillcolor="#e581397f"] ;
# 441 -> 443 ;
# 444 [label="days.with.cr.line <= 614.5209\ngini = 0.32\nsamples = 10\nvalue = [8, 2]", fillcolor="#e58139bf"] ;
# 443 -> 444 ;
# 445 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 444 -> 445 ;
# 446 [label="inq.last.6mths <= 5.0\ngini = 0.1975\nsamples = 9\nvalue = [8, 1]", fillcolor="#e58139df"] ;
# 444 -> 446 ;
# 447 [label="gini = 0.0\nsamples = 8\nvalue = [8, 0]", fillcolor="#e58139ff"] ;
# 446 -> 447 ;
# 448 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 446 -> 448 ;
# 449 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]", fillcolor="#399de5ff"] ;
# 443 -> 449 ;
# 450 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]", fillcolor="#399de5ff"] ;
# 428 -> 450 ;
# 451 [label="installment <= 497.52\ngini = 0.1676\nsamples = 65\nvalue = [59, 6]", fillcolor="#e58139e5"] ;
# 427 -> 451 ;
# 452 [label="revol.util <= 55.05\ngini = 0.3107\nsamples = 26\nvalue = [21, 5]", fillcolor="#e58139c2"] ;
# 451 -> 452 ;
# 453 [label="gini = 0.0\nsamples = 13\nvalue = [13, 0]", fillcolor="#e58139ff"] ;
# 452 -> 453 ;
# 454 [label="fico <= 702.0\ngini = 0.4734\nsamples = 13\nvalue = [8, 5]", fillcolor="#e5813960"] ;
# 452 -> 454 ;
# ...
# 1872 -> 1878 ;
# 1879 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 1878 -> 1879 ;
# 1880 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]", fillcolor="#e58139ff"] ;
# 1878 -> 1880 ;
# 1881 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 1869 -> 1881 ;
# 1882 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 1856 -> 1882 ;
# 1883 [label="gini = 0.0\nsamples = 35\nvalue = [35, 0]", fillcolor="#e58139ff"] ;
# 1855 -> 1883 ;
# 1884 [label="installment <= 186.555\ngini = 0.48\nsamples = 5\nvalue = [3, 2]", fillcolor="#e5813955"] ;
# 1854 -> 1884 ;
# 1885 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]", fillcolor="#399de5ff"] ;
# 1884 -> 1885 ;
# 1886 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]", fillcolor="#e58139ff"] ;
# 1884 -> 1886 ;
# 1887 [label="gini = 0.0\nsamples = 36\nvalue = [36, 0]", fillcolor="#e58139ff"] ;
# 1849 -> 1887 ;
# 1888 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 1848 -> 1888 ;
# 1889 [label="installment <= 297.165\ngini = 0.4082\nsamples = 21\nvalue = [15, 6]", fillcolor="#e5813999"] ;
# 1847 -> 1889 ;
# 1890 [label="log.annual.inc <= 11.5855\ngini = 0.4444\nsamples = 6\nvalue = [2, 4]", fillcolor="#399de57f"] ;
# 1889 -> 1890 ;
# 1891 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]", fillcolor="#399de5ff"] ;
# 1890 -> 1891 ;
# 1892 [label="fico <= 669.5\ngini = 0.4444\nsamples = 3\nvalue = [2, 1]", fillcolor="#e581397f"] ;
# 1890 -> 1892 ;
# 1893 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 1892 -> 1893 ;
# 1894 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]", fillcolor="#e58139ff"] ;
# 1892 -> 1894 ;
# 1895 [label="revol.util <= 67.0\ngini = 0.2311\nsamples = 15\nvalue = [13, 2]", fillcolor="#e58139d8"] ;
# 1889 -> 1895 ;
# 1896 [label="revol.util <= 63.8\ngini = 0.48\nsamples = 5\nvalue = [3, 2]", fillcolor="#e5813955"] ;
# 1895 -> 1896 ;
# 1897 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]", fillcolor="#e58139ff"] ;
# 1896 -> 1897 ;
# 1898 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]", fillcolor="#399de5ff"] ;
# 1896 -> 1898 ;
# 1899 [label="gini = 0.0\nsamples = 10\nvalue = [10, 0]", fillcolor="#e58139ff"] ;
# 1895 -> 1899 ;
# 1900 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 1846 -> 1900 ;
# 1901 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 1845 -> 1901 ;
# 1902 [label="log.annual.inc <= 11.2131\ngini = 0.48\nsamples = 5\nvalue = [2, 3]", fillcolor="#399de555"] ;
# 1844 -> 1902 ;
# 1903 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]", fillcolor="#399de5ff"] ;
# 1902 -> 1903 ;
# 1904 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]", fillcolor="#e58139ff"] ;
# 1902 -> 1904 ;
# 1905 [label="gini = 0.0\nsamples = 4\nvalue = [0, 4]", fillcolor="#399de5ff"] ;
# 1719 -> 1905 ;
# 1906 [label="days.with.cr.line <= 5219.9795\ngini = 0.3899\nsamples = 309\nvalue = [227, 82]", fillcolor="#e58139a3"] ;
# 734 -> 1906 ;
# 1907 [label="delinq.2yrs <= 0.5\ngini = 0.4456\nsamples = 194\nvalue = [129, 65]", fillcolor="#e581397f"] ;
# 1906 -> 1907 ;
# 1908 [label="dti <= 0.845\ngini = 0.4232\nsamples = 171\nvalue = [119, 52]", fillcolor="#e5813990"] ;
# 1907 -> 1908 ;
# 1909 [label="gini = 0.0\nsamples = 11\nvalue = [11, 0]", fillcolor="#e58139ff"] ;
# 1908 -> 1909 ;
# 1910 [label="installment <= 246.945\ngini = 0.4388\nsamples = 160\nvalue = [108, 52]", fillcolor="#e5813984"] ;
# 1908 -> 1910 ;
# 1911 [label="revol.bal <= 19976.0\ngini = 0.3299\nsamples = 48\nvalue = [38, 10]", fillcolor="#e58139bc"] ;
# 1910 -> 1911 ;
# 1912 [label="days.with.cr.line <= 4800.0\ngini = 0.2188\nsamples = 40\nvalue = [35, 5]", fillcolor="#e58139db"] ;
# 1911 -> 1912 ;
# 1913 [label="log.annual.inc <= 9.707\ngini = 0.1841\nsamples = 39\nvalue = [35, 4]", fillcolor="#e58139e2"] ;
# 1912 -> 1913 ;
# 1914 [label="revol.bal <= 2220.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]", fillcolor="#e5813900"] ;
# 1913 -> 1914 ;
# 1915 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]", fillcolor="#e58139ff"] ;
# 1914 -> 1915 ;
# 1916 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]", fillcolor="#399de5ff"] ;
# 1914 -> 1916 ;
# 1917 [label="revol.bal <= 13469.5\ngini = 0.1078\nsamples = 35\nvalue = [33, 2]", fillcolor="#e58139f0"] ;
# 1913 -> 1917 ;
# 1918 [label="fico <= 744.5\ngini = 0.0605\nsamples = 32\nvalue = [31, 1]", fillcolor="#e58139f7"] ;
# 1917 -> 1918 ;
# 1919 [label="gini = 0.0\nsamples = 28\nvalue = [28, 0]", fillcolor="#e58139ff"] ;
# 1918 -> 1919 ;
# 1920 [label="days.with.cr.line <= 2460.021\ngini = 0.375\nsamples = 4\nvalue = [3, 1]", fillcolor="#e58139aa"] ;
# 1918 -> 1920 ;
# 1921 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 1920 -> 1921 ;
# 1922 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]", fillcolor="#e58139ff"] ;
# 1920 -> 1922 ;
# 1923 [label="fico <= 677.0\ngini = 0.4444\nsamples = 3\nvalue = [2, 1]", fillcolor="#e581397f"] ;
# 1917 -> 1923 ;
# 1924 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]", fillcolor="#e58139ff"] ;
# 1923 -> 1924 ;
# 1925 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 1923 -> 1925 ;
# 1926 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 1912 -> 1926 ;
# 1927 [label="int.rate <= 0.1391\ngini = 0.4688\nsamples = 8\nvalue = [3, 5]", fillcolor="#399de566"] ;
# 1911 -> 1927 ;
# 1928 [label="dti <= 20.485\ngini = 0.375\nsamples = 4\nvalue = [3, 1]", fillcolor="#e58139aa"] ;
# 1927 -> 1928 ;
# 1929 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]", fillcolor="#e58139ff"] ;
# 1928 -> 1929 ;
# 1930 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 1928 -> 1930 ;
# 1931 [label="gini = 0.0\nsamples = 4\nvalue = [0, 4]", fillcolor="#399de5ff"] ;
# 1927 -> 1931 ;
# 1932 [label="days.with.cr.line <= 4420.9795\ngini = 0.4688\nsamples = 112\nvalue = [70, 42]", fillcolor="#e5813966"] ;
# 1910 -> 1932 ;
# 1933 [label="revol.bal <= 30327.0\ngini = 0.4884\nsamples = 92\nvalue = [53, 39]", fillcolor="#e5813943"] ;
# 1932 -> 1933 ;
# 1934 [label="fico <= 679.5\ngini = 0.4738\nsamples = 83\nvalue = [51, 32]", fillcolor="#e581395f"] ;
# 1933 -> 1934 ;
# 1935 [label="revol.util <= 85.65\ngini = 0.142\nsamples = 13\nvalue = [12, 1]", fillcolor="#e58139ea"] ;
# 1934 -> 1935 ;
# 1936 [label="gini = 0.0\nsamples = 11\nvalue = [11, 0]", fillcolor="#e58139ff"] ;
# 1935 -> 1936 ;
# 1937 [label="int.rate <= 0.1874\ngini = 0.5\nsamples = 2\nvalue = [1, 1]", fillcolor="#e5813900"] ;
# 1935 -> 1937 ;
# 1938 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]", fillcolor="#e58139ff"] ;
# 1937 -> 1938 ;
# 1939 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 1937 -> 1939 ;
# 1940 [label="dti <= 3.17\ngini = 0.4935\nsamples = 70\nvalue = [39, 31]", fillcolor="#e5813934"] ;
# 1934 -> 1940 ;
# 1941 [label="gini = 0.0\nsamples = 5\nvalue = [0, 5]", fillcolor="#399de5ff"] ;
# 1940 -> 1941 ;
# 1942 [label="dti <= 4.805\ngini = 0.48\nsamples = 65\nvalue = [39, 26]", fillcolor="#e5813955"] ;
# 1940 -> 1942 ;
# 1943 [label="gini = 0.0\nsamples = 7\nvalue = [7, 0]", fillcolor="#e58139ff"] ;
# 1942 -> 1943 ;
# 1944 [label="dti <= 6.445\ngini = 0.4946\nsamples = 58\nvalue = [32, 26]", fillcolor="#e5813930"] ;
# 1942 -> 1944 ;
# 1945 [label="revol.bal <= 971.5\ngini = 0.2778\nsamples = 6\nvalue = [1, 5]", fillcolor="#399de5cc"] ;
# 1944 -> 1945 ;
# 1946 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]", fillcolor="#e58139ff"] ;
# 1945 -> 1946 ;
# 1947 [label="gini = 0.0\nsamples = 5\nvalue = [0, 5]", fillcolor="#399de5ff"] ;
# 1945 -> 1947 ;
# 1948 [label="revol.bal <= 23284.5\ngini = 0.4815\nsamples = 52\nvalue = [31, 21]", fillcolor="#e5813952"] ;
# 1944 -> 1948 ;
# 1949 [label="int.rate <= 0.112\ngini = 0.4978\nsamples = 45\nvalue = [24, 21]", fillcolor="#e5813920"] ;
# 1948 -> 1949 ;
# 1950 [label="gini = 0.0\nsamples = 6\nvalue = [6, 0]", fillcolor="#e58139ff"] ;
# 1949 -> 1950 ;
# 1951 [label="log.annual.inc <= 10.7559\ngini = 0.497\nsamples = 39\nvalue = [18, 21]", fillcolor="#399de524"] ;
# 1949 -> 1951 ;
# 1952 [label="int.rate <= 0.1518\ngini = 0.355\nsamples = 13\nvalue = [3, 10]", fillcolor="#399de5b3"] ;
# 1951 -> 1952 ;
# 1953 [label="gini = 0.0\nsamples = 7\nvalue = [0, 7]", fillcolor="#399de5ff"] ;
# 1952 -> 1953 ;
# 1954 [label="fico <= 707.0\ngini = 0.5\nsamples = 6\nvalue = [3, 3]", fillcolor="#e5813900"] ;
# 1952 -> 1954 ;
# 1955 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]", fillcolor="#399de5ff"] ;
# 1954 -> 1955 ;
# 1956 [label="days.with.cr.line <= 1289.9792\ngini = 0.375\nsamples = 4\nvalue = [3, 1]", fillcolor="#e58139aa"] ;
# 1954 -> 1956 ;
# 1957 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 1956 -> 1957 ;
# 1958 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]", fillcolor="#e58139ff"] ;
# 1956 -> 1958 ;
# 1959 [label="int.rate <= 0.1205\ngini = 0.4882\nsamples = 26\nvalue = [15, 11]", fillcolor="#e5813944"] ;
# 1951 -> 1959 ;
# 1960 [label="gini = 0.0\nsamples = 4\nvalue = [0, 4]", fillcolor="#399de5ff"] ;
# 1959 -> 1960 ;
# 1961 [label="fico <= 744.5\ngini = 0.4339\nsamples = 22\nvalue = [15, 7]", fillcolor="#e5813988"] ;
# 1959 -> 1961 ;
# 1962 [label="int.rate <= 0.1583\ngini = 0.2907\nsamples = 17\nvalue = [14, 3]", fillcolor="#e58139c8"] ;
# 1961 -> 1962 ;
# 1963 [label="gini = 0.0\nsamples = 11\nvalue = [11, 0]", fillcolor="#e58139ff"] ;
# 1962 -> 1963 ;
# 1964 [label="revol.bal <= 6428.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]", fillcolor="#e5813900"] ;
# 1962 -> 1964 ;
# 1965 [label="revol.bal <= 2647.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]", fillcolor="#399de5aa"] ;
# 1964 -> 1965 ;
# 1966 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]", fillcolor="#e58139ff"] ;
# 1965 -> 1966 ;
# 1967 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]", fillcolor="#399de5ff"] ;
# 1965 -> 1967 ;
# 1968 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]", fillcolor="#e58139ff"] ;
# 1964 -> 1968 ;
# 1969 [label="revol.util <= 13.75\ngini = 0.32\nsamples = 5\nvalue = [1, 4]", fillcolor="#399de5bf"] ;
# 1961 -> 1969 ;
# 1970 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]", fillcolor="#399de5ff"] ;
# 1969 -> 1970 ;
# 1971 [label="dti <= 16.165\ngini = 0.5\nsamples = 2\nvalue = [1, 1]", fillcolor="#e5813900"] ;
# 1969 -> 1971 ;
# 1972 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]", fillcolor="#e58139ff"] ;
# 1971 -> 1972 ;
# 1973 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 1971 -> 1973 ;
# 1974 [label="gini = 0.0\nsamples = 7\nvalue = [7, 0]", fillcolor="#e58139ff"] ;
# 1948 -> 1974 ;
# 1975 [label="dti <= 18.735\ngini = 0.3457\nsamples = 9\nvalue = [2, 7]", fillcolor="#399de5b6"] ;
# 1933 -> 1975 ;
# 1976 [label="gini = 0.0\nsamples = 7\nvalue = [0, 7]", fillcolor="#399de5ff"] ;
# 1975 -> 1976 ;
# 1977 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]", fillcolor="#e58139ff"] ;
# 1975 -> 1977 ;
# 1978 [label="fico <= 779.5\ngini = 0.255\nsamples = 20\nvalue = [17, 3]", fillcolor="#e58139d2"] ;
# 1932 -> 1978 ;
# 1979 [label="days.with.cr.line <= 5204.9795\ngini = 0.1049\nsamples = 18\nvalue = [17, 1]", fillcolor="#e58139f0"] ;
# 1978 -> 1979 ;
# 1980 [label="gini = 0.0\nsamples = 17\nvalue = [17, 0]", fillcolor="#e58139ff"] ;
# 1979 -> 1980 ;
# 1981 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 1979 -> 1981 ;
# 1982 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]", fillcolor="#399de5ff"] ;
# 1978 -> 1982 ;
# 1983 [label="revol.util <= 34.7\ngini = 0.4915\nsamples = 23\nvalue = [10, 13]", fillcolor="#399de53b"] ;
# 1907 -> 1983 ;
# 1984 [label="gini = 0.0\nsamples = 6\nvalue = [6, 0]", fillcolor="#e58139ff"] ;
# 1983 -> 1984 ;
# 1985 [label="log.annual.inc <= 11.6826\ngini = 0.3599\nsamples = 17\nvalue = [4, 13]", fillcolor="#399de5b1"] ;
# 1983 -> 1985 ;
# 1986 [label="revol.util <= 41.95\ngini = 0.2311\nsamples = 15\nvalue = [2, 13]", fillcolor="#399de5d8"] ;
# 1985 -> 1986 ;
# 1987 [label="fico <= 684.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]", fillcolor="#e5813900"] ;
# 1986 -> 1987 ;
# 1988 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]", fillcolor="#e58139ff"] ;
# 1987 -> 1988 ;
# 1989 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]", fillcolor="#399de5ff"] ;
# 1987 -> 1989 ;
# 1990 [label="gini = 0.0\nsamples = 11\nvalue = [0, 11]", fillcolor="#399de5ff"] ;
# 1986 -> 1990 ;
# 1991 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]", fillcolor="#e58139ff"] ;
# 1985 -> 1991 ;
# 1992 [label="fico <= 664.5\ngini = 0.2519\nsamples = 115\nvalue = [98, 17]", fillcolor="#e58139d3"] ;
# 1906 -> 1992 ;
# 1993 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]", fillcolor="#399de5ff"] ;
# 1992 -> 1993 ;
# 1994 [label="dti <= 8.96\ngini = 0.2302\nsamples = 113\nvalue = [98, 15]", fillcolor="#e58139d8"] ;
# 1992 -> 1994 ;
# 1995 [label="int.rate <= 0.0948\ngini = 0.0677\nsamples = 57\nvalue = [55, 2]", fillcolor="#e58139f6"] ;
# 1994 -> 1995 ;
# 1996 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 1995 -> 1996 ;
# 1997 [label="installment <= 880.705\ngini = 0.0351\nsamples = 56\nvalue = [55, 1]", fillcolor="#e58139fa"] ;
# 1995 -> 1997 ;
# 1998 [label="gini = 0.0\nsamples = 54\nvalue = [54, 0]", fillcolor="#e58139ff"] ;
# 1997 -> 1998 ;
# 1999 [label="dti <= 4.8\ngini = 0.5\nsamples = 2\nvalue = [1, 1]", fillcolor="#e5813900"] ;
# 1997 -> 1999 ;
# 2000 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 1999 -> 2000 ;
# 2001 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]", fillcolor="#e58139ff"] ;
# 1999 -> 2001 ;
# 2002 [label="dti <= 13.685\ngini = 0.3565\nsamples = 56\nvalue = [43, 13]", fillcolor="#e58139b2"] ;
# 1994 -> 2002 ;
# 2003 [label="fico <= 757.0\ngini = 0.4938\nsamples = 18\nvalue = [10, 8]", fillcolor="#e5813933"] ;
# 2002 -> 2003 ;
# 2004 [label="revol.bal <= 23073.0\ngini = 0.4444\nsamples = 15\nvalue = [10, 5]", fillcolor="#e581397f"] ;
# 2003 -> 2004 ;
# 2005 [label="int.rate <= 0.141\ngini = 0.2778\nsamples = 12\nvalue = [10, 2]", fillcolor="#e58139cc"] ;
# 2004 -> 2005 ;
# 2006 [label="gini = 0.0\nsamples = 7\nvalue = [7, 0]", fillcolor="#e58139ff"] ;
# 2005 -> 2006 ;
# 2007 [label="days.with.cr.line <= 7063.4795\ngini = 0.48\nsamples = 5\nvalue = [3, 2]", fillcolor="#e5813955"] ;
# 2005 -> 2007 ;
# 2008 [label="days.with.cr.line <= 6260.9795\ngini = 0.4444\nsamples = 3\nvalue = [1, 2]", fillcolor="#399de57f"] ;
# 2007 -> 2008 ;
# 2009 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]", fillcolor="#e58139ff"] ;
# 2008 -> 2009 ;
# 2010 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]", fillcolor="#399de5ff"] ;
# 2008 -> 2010 ;
# 2011 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]", fillcolor="#e58139ff"] ;
# 2007 -> 2011 ;
# 2012 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]", fillcolor="#399de5ff"] ;
# 2004 -> 2012 ;
# 2013 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]", fillcolor="#399de5ff"] ;
# 2003 -> 2013 ;
# 2014 [label="revol.bal <= 125210.0\ngini = 0.2285\nsamples = 38\nvalue = [33, 5]", fillcolor="#e58139d8"] ;
# 2002 -> 2014 ;
# 2015 [label="installment <= 752.81\ngini = 0.1928\nsamples = 37\nvalue = [33, 4]", fillcolor="#e58139e0"] ;
# 2014 -> 2015 ;
# 2016 [label="int.rate <= 0.1687\ngini = 0.0644\nsamples = 30\nvalue = [29, 1]", fillcolor="#e58139f6"] ;
# 2015 -> 2016 ;
# 2017 [label="gini = 0.0\nsamples = 27\nvalue = [27, 0]", fillcolor="#e58139ff"] ;
# 2016 -> 2017 ;
# 2018 [label="log.annual.inc <= 11.2039\ngini = 0.4444\nsamples = 3\nvalue = [2, 1]", fillcolor="#e581397f"] ;
# 2016 -> 2018 ;
# 2019 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]", fillcolor="#e58139ff"] ;
# 2018 -> 2019 ;
# 2020 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 2018 -> 2020 ;
# 2021 [label="revol.util <= 9.1\ngini = 0.4898\nsamples = 7\nvalue = [4, 3]", fillcolor="#e5813940"] ;
# 2015 -> 2021 ;
# 2022 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]", fillcolor="#e58139ff"] ;
# 2021 -> 2022 ;
# 2023 [label="installment <= 858.2\ngini = 0.48\nsamples = 5\nvalue = [2, 3]", fillcolor="#399de555"] ;
# 2021 -> 2023 ;
# 2024 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]", fillcolor="#399de5ff"] ;
# 2023 -> 2024 ;
# 2025 [label="revol.util <= 72.75\ngini = 0.4444\nsamples = 3\nvalue = [2, 1]", fillcolor="#e581397f"] ;
# 2023 -> 2025 ;
# 2026 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]", fillcolor="#e58139ff"] ;
# 2025 -> 2026 ;
# 2027 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 2025 -> 2027 ;
# 2028 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]", fillcolor="#399de5ff"] ;
# 2014 -> 2028 ;
# }

# %% [markdown]
# ## Apply cross validation

# %%
from sklearn.model_selection import cross_val_score
dtree = DecisionTreeClassifier()
scores = cross_val_score(dtree, X, y, cv=10, scoring='accuracy')
print(scores.mean())
# Out:
# 0.707108750658
