# %% [markdown]
# ## Simple linear regression
# A statistical method that allows us to summarize and study relationships between two continuous (quantitative) variables:
#
#     One variable, denoted x, is regarded as the predictor, explanatory, or independent variable.
#     The other variable, denoted y, is regarded as the response, outcome, or dependent variable.
#
# https://onlinecourses.science.psu.edu/stat501/node/251

# %%
from IPython.display import Image
Image(filename='lr1.jpeg')

# %%
from IPython.display import Image
Image(filename='lr2.jpeg')

# %% [markdown]
# ###  Fitting a line
#
# Given a scatter plot of Y vs X, fit a straight line through the points so that the sum of the vertical distances between points and the line is minimized
#
# Best line is the one with least residuals

# %% [markdown]
# ### Linear Regression
#
#     One independent variable and one dependaent variable
#
#
# ### Multiple Regression
#
#     More than one independent variables used to predict the dependent variable
