# %% [markdown]
# ## Neural Networks
#
#     Neural Networks are inspired from human brains
#     These are black box methods
#     Allows computers to learn in a similar manner to humans

# %% [markdown]
# ##  Some use cases of NN
#
#     Self driving cars
#     Face ID
#     Pattern recognition

# %%
from IPython.display import Image
Image(filename='nn_1.jpg')

# %% [markdown]
# ##  Perceptron
#
#     A perceptron consists of one or more inputs, a processor and a single output
#     It follows 'feed-forward' model, which means inputs are sent to the neuron for processing and results an output

# %%
# Perceptron
Image(filename='nn_2.png')

# %% [markdown]
# ## Neural Networks
#
#     NN has one input layer and one output layer
#     All intermediate layers are called as hidden layers

# %%
Image(filename='nn_3.png')

# %% [markdown]
# ## Deep Learning
#
#     Deep Learnig is nothing but a Neural Network with multiple hidden layers

# %%
Image(filename='nn_4.png')

# %% [markdown]
# ###  Open source deep learning libraries
#
#     Tensor Flow
#         Core implementation
#         contrib.learn
#     Theano
#     Keras - Uses either Theano or Tensor Flow as backend

# %% [markdown]
# ####  Tensor Flow: https://www.tensorflow.org/

# %% [markdown]
# ## Installation
#
#     conda install tensorflow

# %% [markdown]
# ##  Basics of Tensor Flow
#
#     Widely used for Deep Learning
#     Developed by Google
#     Run on CPUs or GPUs
#     Deep learning algorithms work faster on GPUs
#
#     Basic idea of TF is to create data flow graphs
#     The data passed along from layer of nodes to layer of node is known as a Tensor
#
#     Theme: Tensors are flowing through data graphs
#
#     Two ways to use TF:
#         Customizable graph session
#         Scikit Learn type interface with Contrib.Learn

# %% [markdown]
# ## Keras - https://keras.io/
#
#     Easy and fast prototyping
#     Runs on top of TensorFlow or CNTK or Theano

# %% [markdown]
# ## Convolutional Neural Networks

# %%
Image(filename='cnn.jpg')

# %% [markdown]
# ## Recurrent Neural Networks
#
#     Time Series Data
#         when you want to predict future behavior based on past behavior
#         Self driving car based on past trajectories
#     Machine translation
#     Sentiment analysis - where sequence of words matter

# %% [markdown]
# ###  Ex: http://nlp.stanford.edu:8080/sentiment/rntnDemo.html

# %%
Image(filename='rnn.jpg')

# %% [markdown]
# ## RNN Topologies
#
#     Sequence to Sequence - Predict stock prices based on historical data
#     Sequence to Vector - Words in a sentence to sentiment
#     Vector to Sequence - Create captions for an image
#     Ecoder -> Decoder - Machine translation
