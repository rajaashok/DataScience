# %% [markdown]
# ## Goal:
#
# The goal of ensemble methods is to combine different classifiers into a meta classifier. Voting is taken on all the predictions from different classifiers, to predict the final outcome

# %% [markdown]
# # Ensemble methods

# %%
from IPython.display import Image
Image('em_1.png', width=700)

# %% [markdown]
# # Bagging
#
#     Bagging is closely related to previous diagram, but the only difference is in choosing the training sets
#     Instead of using same training set for all the classifiers, we draw bootstrap samples from training set in bagging
#     Bootstrap samples - random samples with replacement
#     Bagging is also known as Bootstrap Aggregating
#     Random Forests is closely related to Bagging, where we use random feature subsets to fit individual decision trees

# %%
Image('em_2.png', width=700)

# %%
# Bootstrap sampling (select random samples with replacement)
Image('em_3.png', width=700)

# %% [markdown]
# # Boosting
#
#     Boosting is the most powerful technique
#     Widely used in competitions
#     Similar to bagging, with few differences
#
#
#
#     The key concept behind boosting is to let the weak learners subsequently learn from misclassified training samples to improve the performance of ensemble method
#
#     Steps:
#         1. Draw a random subset of training samples without replacement, to train the weak learner w1
#         2. Draw second random training subset without replacement, and add 50% of misclassified samples from previous weak learner w1 to train a new weak learner w2
#         3. Find the training samples based on w1 and w2 disagreed samples to train third weak learner w3
#         4. Combine weak learners via majority voting
#
#
#      Popular ones:
#          1. AdaBoost - Adaptive Boosting
#          2. Gradient Boosting

# %%
Image('boosting.jpg', width=700)

# %%
Image('ada.png', width=700)

# %% [markdown]
# ## AdaBoost vs GradientBoost
#
# AdaBoost is the shortcut for adaptive boosting. So what’s the differences between Adaptive boosting and Gradient boosting?
#
# Both are boosting algorithms which means that they convert a set of weak learners into a single strong learner. They both initialize a strong learner (usually a decision tree) and iteratively create a weak learner that is added to the strong learner. They differ on how they create the weak learners during the iterative process.
#
# At each iteration, adaptive boosting changes the sample distribution by modifying the weights attached to each of the instances. It increases the weights of the wrongly predicted instances and decreases the ones of the correctly predicted instances. The weak learner thus focuses more on the difficult instances. After being trained, the weak learner is added to the strong one according to his performance (so-called alpha weight). The higher it performs, the more it contributes to the strong learner.
#
# On the other hand, gradient boosting doesn’t modify the sample distribution. Instead of training on a newly sample distribution, the weak learner trains on the remaining errors (so-called pseudo-residuals) of the strong learner. It is another way to give more importance to the difficult instances. At each iteration, the pseudo-residuals are computed and a weak learner is fitted to these pseudo-residuals. Then, the contribution of the weak learner (so-called multiplier) to the strong one isn’t computed according to his performance on the newly distribution sample but using a gradient descent optimization process. The computed contribution is the one minimizing the overall error of the strong learner.

# %% [markdown]
# ##  Bagging vs Boosting

# %%
Image('em_4.png', width=700)

# %% [markdown]
# ### More resources
#
# ##### https://machinelearningmastery.com/ensemble-machine-learning-algorithms-python-scikit-learn/
# ##### https://martin-thoma.com/ensembles/
# ##### https://github.com/knathanieltucker/bit-of-data-science-and-scikit-learn/blob/master/notebooks/EnsembleMethods.ipynb
