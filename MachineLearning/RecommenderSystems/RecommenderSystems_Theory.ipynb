# %% [markdown]
# ## Recommendation Engine
#
#
#     Also known as Collaborative filtering
#     Recommend items based on similarity
#
#     Use cases:
#
#         Netflix movie recommendation
#         Amazon product recommendation
#         Youtube video recommendation

# %% [markdown]
# ##  Types of recommendations
#
#     User based recommendations
#     Item based recommendations

# %%
from IPython.display import Image
Image(filename='r1.jpg')

# %% [markdown]
# ####  User Based
#
#     Identify similar users and form user neighborhoods
#     If one user buys a new product, recommend that to all users in the neighborhood
#
# #### Item Based
#
#     Identify items that are frequenctly bought together
#     If one item is bought by a user, recommend the related items to the user
#     Users who bought this also bought
